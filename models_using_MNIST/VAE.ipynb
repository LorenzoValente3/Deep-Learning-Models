# %%
import tensorflow as tf
from tensorflow.python.keras import Input
#from tensorflow.python.keras.engine.functional import Functional
#from tensorflow.python.keras.engine.keras_tensor import KerasTensor
from tensorflow.python.keras.models import Model, Sequential

import numpy as np
from matplotlib import pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Dense, Lambda
#from tensorflow.keras import layers

#from tensorflow.python.keras.utils.np_utils import to_categorical
from tensorflow.python.keras.regularizers import l2
from tensorflow.keras import backend as K
tf.compat.v1.disable_eager_execution()


#from scipy.stats import norm

import tensorflow.python.util.deprecation as deprecation
deprecation._PRINT_DEPRECATION_WARNINGS = False

# %% [markdown]
# ## Import the MNIST data class and call it.

# %%
import MNIST_dataset as mnist
data = mnist.MNISTData()

# %% [markdown]
# # Variational Autoencoder using Keras
# The aim of this class is to implement the variational autoencoder and to test it on the MNIST dataset and then build a variational autoencoder that is able to classify MNIST data in its latent dimension with gaussian noise applied to the orignal images.
#
# Code partially adapted from [Keras Documentation](https://keras.io/examples/generative/vae/).

# %%
class VAE:
    """Variational Autencoder Class"""
    def __init__(self, data: mnist.MNISTData, num_classes=10):
        self.x_train = data.x_train
        self.x_test = data.x_test
        self.y_train = data.y_train
        self.y_test = data.y_test

        self.num_classes = num_classes
        self.input_shape = self.x_train[0].shape
        self.input = Input(shape=self.input_shape,name='encoder_input')
        self.latent_dim = 2

        self.encoder = None
        self.encoder_model = None

        self.decoder = None
        self.VAE = None
        self.encoded_mean = None
        self.encoded_var = None
        self.decoder_model=None
        
    def build_encoder(self):
        """Building the encoder architecture for the variational autoencoder. 
        The final encoding dimension is 2. 
        """
        self.encoder = Dense(512, activation='relu')(self.input)
        self.encoder = Dense(64, activation='relu')(self.encoder)
        self.encoded_mean = Dense(self.latent_dim)(self.encoder)
        self.encoded_var = Dense(self.latent_dim)(self.encoder)
        self.encoder = Lambda(self.sampling, output_shape=(self.latent_dim,), name = 'encoder_output')([self.encoded_mean, self.encoded_var])

        #building a model for the encoder in order to be able to predict and plot the latent dimension
        self.encoder_model = Model(self.input, [self.encoded_mean, self.encoded_var, self.encoder], name='encoder')
    
    def build_decoder(self):
        """Building the decoder architecture and storing the output in self.decoder."""
        if self.encoder is None:
            raise RuntimeError("The encoder has to be built before you can build the decoder!")        

        self.decoder = Dense(64, activation='relu')(self.encoder)
        self.decoder = Dense(512, activation='relu')(self.decoder)
        self.decoder = Dense(784, activation='sigmoid', name='decoder_output')(self.decoder)
        
    def build_classifier(self):
        """ Building the classifier architecture, using self.encoder as input."""

        if self.encoder is None:
            raise RuntimeError("The encoder has to be built before you can build the classifier!")
        if self.decoder is None:
            raise RuntimeError("The decoder has to be built before you can build the autoencoder!")
        self.latent_classifier = Dense(128, kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01), activation='relu')(self.encoder)
        self.latent_classifier = Dense(64,  kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01), activation='relu')(self.latent_classifier)
        self.latent_classifier = Dense(32,  kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01), activation='relu')(self.latent_classifier)

        self.latent_classifier = Dense(self.num_classes, activation='softmax',name='classifier_output')(self.latent_classifier)
        
    def build_vae(self, use_latent_classifier=False):
        """ Building the whole variational autoencoder Model from self.encoder and self.decoder with 
        self.input as input. It is used self.custom_loss as the model loss function.
        """
        if self.encoder is None:
            raise RuntimeError("The encoder has to be built before you can build the autoencoder!")
        if self.decoder is None:
            raise RuntimeError("The decoder has to be built before you can build the autoencoder!")
        
        if use_latent_classifier:
            if self.latent_classifier is None:
                raise RuntimeError("If you want to use the option with the latent classifier, you have to build it "
                                   "beforehand!")
            self.VAE = Model(self.input, outputs=[self.decoder, self.latent_classifier])
            self.VAE.compile(loss=self.custom_loss(self.encoded_mean, self.encoded_var), loss_weights=[1, 0.1], optimizer='adam')#, metrics="accuracy")
        else:
            self.VAE = Model(self.input, outputs=self.decoder)
            self.VAE.compile(optimizer='adam', loss=self.custom_loss(self.encoded_mean, self.encoded_var))
            self.VAE.summary()

    def sampling(self, args):
        """ Implement the Reparameterization trick. The function returns
         a vector randomly sampled from the latent space.
         # Arguments
        args (tensor): mean and log of variance of Q(z|X)
         # Returns
            z (tensor): sampled latent vector   
        """
        z_mean, z_log_var = args
        batch = K.shape(z_mean)[0]
        dim = K.int_shape(z_mean)[1]
        # we apply the multigaussian noise to every points at once
        epsilon = K.random_normal(shape=(batch, dim))
        return z_mean + K.exp(0.5 * z_log_var) * epsilon
    

    def custom_loss(self, mean, var):
        """Implement the loss function for the variational autoencoder."""
        
        def loss(y_true, y_pred):

            reconstruction_loss = tf.losses.mean_squared_error(y_true, y_pred)*784
            kl_loss = 1. + var - K.square(mean) - K.exp(var)
            kl_loss = K.sum(kl_loss, axis=-1)
            kl_loss *= -0.5
            beta = 1.0*10**-2
            return K.mean(reconstruction_loss + beta*kl_loss)

        return loss
        
        
    def fit_data(self, batch_size=128, epochs=40, use_latent_classifier=False):
        """Write the fit function for the autoencoder. 
        Store the fit history in self.history to be able to plot the fitting scores."""
        
        if use_latent_classifier:
            self.history = self.VAE.fit(self.x_train, [self.x_train, self.y_train],
                                                validation_data=(self.x_test, [self.x_test, self.y_test]),
                                                batch_size=batch_size, epochs=epochs,
                                                shuffle=True,
                                                )
        else:
            self.history = self.VAE.fit(self.x_train, self.x_train, validation_data=(self.x_test, self.x_test),
                                                batch_size=batch_size, epochs=epochs,
                                                shuffle=True,
                                                )
        
        self.history = self.history.history

    def dir(self):
        """Creation of the directories"""
        dir = os.path.join("images")
        if not os.path.exists(dir):
            os.mkdir(dir)
        dir2 = os.path.join("./images/VAE")
        if not os.path.exists(dir2):
            os.mkdir(dir2)
    
    def plot_score(self, model_name=None):
        """Plots the scores achieved during the fitting."""
        plt.plot(self.history['loss'])
        plt.plot(self.history['val_loss'])
        plt.ylabel('Model Accuracy')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Test'], loc='best')
        plt.title('Accuracy of {model_name}'.format(model_name=model_name))
        
        self.dir()
        plt.savefig('./images/VAE/Accuracy of {model_name}.png'.format(model_name=model_name))
        
        plt.show()

    def plot_latent_dimension(self, model_name=None):
        """Plots the latent dimension of the autoencoder."""
        prediction = self.encoder_model.predict(self.x_test)
        fig = plt.figure(figsize=(10, 10))
        fig.patch.set_facecolor("white")
        plt.scatter(prediction[2][:, 0], prediction[2][:, 1], c=np.argmax(self.y_test, axis=1) , cmap="Set3")
        plt.colorbar()
        
        self.dir()
        plt.savefig('./images/VAE/Latent dimension of {model_name}.png'.format(model_name=model_name))

        plt.show()

# %%
network = VAE(data)
network.build_encoder()
network.build_decoder()
network.build_vae()
network.fit_data()
network.dir()
network.plot_latent_dimension("Variational Autoencoder without classifier")
network.plot_score("Variational Autoencoder without classifier")
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      [(None, 784)]        0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          401920      encoder_input[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           32832       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 2)            130         dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2)            130         dense_1[0][0]
# __________________________________________________________________________________________________
# encoder_output (Lambda)         (None, 2)            0           dense_2[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           192         encoder_output[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 512)          33280       dense_4[0][0]
# __________________________________________________________________________________________________
# decoder_output (Dense)          (None, 784)          402192      dense_5[0][0]
# ==================================================================================================
# Total params: 870,676
# Trainable params: 870,676
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/40
# 60000/60000 [==============================] - 5s 84us/sample - loss: 45.4586 - val_loss: 37.7545
# Epoch 2/40
# 60000/60000 [==============================] - 5s 86us/sample - loss: 36.1897 - val_loss: 35.1518
# Epoch 3/40
# 60000/60000 [==============================] - 5s 86us/sample - loss: 34.2431 - val_loss: 33.6517
# Epoch 4/40
# 60000/60000 [==============================] - 5s 85us/sample - loss: 33.1028 - val_loss: 32.9174
# Epoch 5/40
# 60000/60000 [==============================] - 5s 86us/sample - loss: 32.2752 - val_loss: 32.2597
# Epoch 6/40
# 60000/60000 [==============================] - 5s 86us/sample - loss: 31.7149 - val_loss: 31.7237
# Epoch 7/40
# 60000/60000 [==============================] - 5s 86us/sample - loss: 31.2459 - val_loss: 31.2232
# Epoch 8/40
# 60000/60000 [==============================] - 5s 87us/sample - loss: 30.8764 - val_loss: 30.9700
# Epoch 9/40
# 60000/60000 [==============================] - 5s 85us/sample - loss: 30.4908 - val_loss: 30.6696
# Epoch 10/40
# 60000/60000 [==============================] - 5s 87us/sample - loss: 30.2086 - val_loss: 30.4423
# Epoch 11/40
# 60000/60000 [==============================] - 5s 86us/sample - loss: 29.9459 - val_loss: 30.2337
# Epoch 12/40
# 60000/60000 [==============================] - 5s 88us/sample - loss: 29.7132 - val_loss: 30.0586
# Epoch 13/40
# 60000/60000 [==============================] - 5s 84us/sample - loss: 29.4891 - val_loss: 29.7921
# Epoch 14/40
# 60000/60000 [==============================] - 5s 85us/sample - loss: 29.3069 - val_loss: 29.4643
# Epoch 15/40
# 60000/60000 [==============================] - 5s 85us/sample - loss: 29.1065 - val_loss: 29.5373
# Epoch 16/40
# 60000/60000 [==============================] - 5s 84us/sample - loss: 28.9309 - val_loss: 29.4763
# Epoch 17/40
# 60000/60000 [==============================] - 5s 85us/sample - loss: 28.8177 - val_loss: 29.2479
# Epoch 18/40
# 60000/60000 [==============================] - 5s 86us/sample - loss: 28.6554 - val_loss: 29.2346
# Epoch 19/40
# 60000/60000 [==============================] - 5s 84us/sample - loss: 28.5705 - val_loss: 29.0988
# Epoch 20/40
# 60000/60000 [==============================] - 5s 83us/sample - loss: 28.4016 - val_loss: 29.1343
# Epoch 21/40
# 60000/60000 [==============================] - 5s 84us/sample - loss: 28.3267 - val_loss: 28.9449
# Epoch 22/40
# 60000/60000 [==============================] - 5s 86us/sample - loss: 28.1711 - val_loss: 28.8831
# Epoch 23/40
# 60000/60000 [==============================] - 5s 87us/sample - loss: 28.1453 - val_loss: 29.0072
# Epoch 24/40
# 60000/60000 [==============================] - 5s 87us/sample - loss: 28.0881 - val_loss: 28.8282
# Epoch 25/40
# 60000/60000 [==============================] - 5s 85us/sample - loss: 27.9452 - val_loss: 28.8501
# Epoch 26/40
# 60000/60000 [==============================] - 5s 87us/sample - loss: 27.8788 - val_loss: 28.7046
# Epoch 27/40
# 60000/60000 [==============================] - 5s 88us/sample - loss: 27.7890 - val_loss: 28.6885
# Epoch 28/40
# 60000/60000 [==============================] - 5s 87us/sample - loss: 27.6495 - val_loss: 28.5820
# Epoch 29/40
# 60000/60000 [==============================] - 5s 84us/sample - loss: 27.5660 - val_loss: 28.5664
# Epoch 30/40
# 60000/60000 [==============================] - 5s 88us/sample - loss: 27.5204 - val_loss: 28.5800
# Epoch 31/40
# 60000/60000 [==============================] - 5s 85us/sample - loss: 27.4855 - val_loss: 28.4751
# Epoch 32/40
# 60000/60000 [==============================] - 5s 85us/sample - loss: 27.4393 - val_loss: 28.3720
# Epoch 33/40
# 60000/60000 [==============================] - 5s 87us/sample - loss: 27.3314 - val_loss: 28.3512
# Epoch 34/40
# 60000/60000 [==============================] - 5s 86us/sample - loss: 27.3152 - val_loss: 28.2601
# Epoch 35/40
# 60000/60000 [==============================] - 6s 92us/sample - loss: 27.2073 - val_loss: 28.2526
# Epoch 36/40
# 60000/60000 [==============================] - 5s 89us/sample - loss: 27.2630 - val_loss: 28.2663
# Epoch 37/40
# 60000/60000 [==============================] - 5s 88us/sample - loss: 27.1705 - val_loss: 28.2870
# Epoch 38/40
# 60000/60000 [==============================] - 5s 87us/sample - loss: 27.1352 - val_loss: 28.2131
# Epoch 39/40
# 60000/60000 [==============================] - 5s 85us/sample - loss: 27.0732 - val_loss: 28.2104
# Epoch 40/40
# 60000/60000 [==============================] - 5s 86us/sample - loss: 26.9835 - val_loss: 28.1402

# %%
network_with_classifier = VAE(data)
network_with_classifier.build_encoder()
network_with_classifier.build_decoder()
network_with_classifier.build_classifier()
network_with_classifier.build_vae(use_latent_classifier=True)
network_with_classifier.fit_data(use_latent_classifier=True)
network_with_classifier.dir()
network_with_classifier.plot_latent_dimension("Variational Autoencoder with classifier")
network_with_classifier.plot_score("Variational Autoencoder with classifier")
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/40
# 60000/60000 [==============================] - 5s 92us/sample - loss: 50.4607 - decoder_output_loss: 45.5544 - classifier_output_loss: 43.7858 - val_loss: 40.7064 - val_decoder_output_loss: 38.0323 - val_classifier_output_loss: 21.9752
# Epoch 2/40
# 60000/60000 [==============================] - 5s 90us/sample - loss: 38.8231 - decoder_output_loss: 36.5941 - classifier_output_loss: 17.3166 - val_loss: 37.1243 - val_decoder_output_loss: 35.1732 - val_classifier_output_loss: 14.6834
# Epoch 3/40
# 60000/60000 [==============================] - 5s 90us/sample - loss: 36.2260 - decoder_output_loss: 34.4908 - classifier_output_loss: 12.6816 - val_loss: 35.2981 - val_decoder_output_loss: 33.6659 - val_classifier_output_loss: 12.1342
# Epoch 4/40
# 60000/60000 [==============================] - 5s 89us/sample - loss: 34.6046 - decoder_output_loss: 33.0830 - classifier_output_loss: 10.8913 - val_loss: 33.8767 - val_decoder_output_loss: 32.3866 - val_classifier_output_loss: 10.7229
# Epoch 5/40
# 60000/60000 [==============================] - 5s 90us/sample - loss: 33.4309 - decoder_output_loss: 32.0419 - classifier_output_loss: 9.8504 - val_loss: 32.9992 - val_decoder_output_loss: 31.6099 - val_classifier_output_loss: 9.7805
# Epoch 6/40
# 60000/60000 [==============================] - 5s 90us/sample - loss: 32.5614 - decoder_output_loss: 31.2713 - classifier_output_loss: 9.0648 - val_loss: 32.4798 - val_decoder_output_loss: 31.0755 - val_classifier_output_loss: 9.7429
# Epoch 7/40
# 60000/60000 [==============================] - 5s 89us/sample - loss: 31.9166 - decoder_output_loss: 30.7000 - classifier_output_loss: 8.5081 - val_loss: 31.8557 - val_decoder_output_loss: 30.5041 - val_classifier_output_loss: 9.3078
# Epoch 8/40
# 60000/60000 [==============================] - 5s 90us/sample - loss: 31.3598 - decoder_output_loss: 30.1985 - classifier_output_loss: 8.0724 - val_loss: 31.3533 - val_decoder_output_loss: 30.0836 - val_classifier_output_loss: 8.7100
# Epoch 9/40
# 60000/60000 [==============================] - 5s 89us/sample - loss: 30.8629 - decoder_output_loss: 29.7540 - classifier_output_loss: 7.7003 - val_loss: 30.9968 - val_decoder_output_loss: 29.7889 - val_classifier_output_loss: 8.8889
# Epoch 10/40
# 60000/60000 [==============================] - 5s 91us/sample - loss: 30.4484 - decoder_output_loss: 29.3864 - classifier_output_loss: 7.3390 - val_loss: 30.8087 - val_decoder_output_loss: 29.6444 - val_classifier_output_loss: 8.8032
# Epoch 11/40
# 60000/60000 [==============================] - 6s 93us/sample - loss: 30.0951 - decoder_output_loss: 29.0646 - classifier_output_loss: 7.1355 - val_loss: 30.4923 - val_decoder_output_loss: 29.3448 - val_classifier_output_loss: 8.4143
# Epoch 12/40
# 60000/60000 [==============================] - 5s 88us/sample - loss: 29.8067 - decoder_output_loss: 28.8051 - classifier_output_loss: 6.9548 - val_loss: 30.2741 - val_decoder_output_loss: 29.1217 - val_classifier_output_loss: 8.3477
# Epoch 13/40
# 60000/60000 [==============================] - 5s 89us/sample - loss: 29.5324 - decoder_output_loss: 28.5574 - classifier_output_loss: 6.7840 - val_loss: 30.2002 - val_decoder_output_loss: 29.0472 - val_classifier_output_loss: 8.2372
# Epoch 14/40
# 60000/60000 [==============================] - 5s 90us/sample - loss: 29.2761 - decoder_output_loss: 28.3254 - classifier_output_loss: 6.6180 - val_loss: 29.8514 - val_decoder_output_loss: 28.7133 - val_classifier_output_loss: 8.1287
# Epoch 15/40
# 60000/60000 [==============================] - 5s 90us/sample - loss: 29.0473 - decoder_output_loss: 28.1168 - classifier_output_loss: 6.5268 - val_loss: 29.8954 - val_decoder_output_loss: 28.7868 - val_classifier_output_loss: 8.3483
# Epoch 16/40
# 60000/60000 [==============================] - 5s 89us/sample - loss: 28.8293 - decoder_output_loss: 27.9199 - classifier_output_loss: 6.3675 - val_loss: 29.8191 - val_decoder_output_loss: 28.7075 - val_classifier_output_loss: 8.3787
# Epoch 17/40
# 60000/60000 [==============================] - 5s 91us/sample - loss: 28.6798 - decoder_output_loss: 27.7839 - classifier_output_loss: 6.3096 - val_loss: 29.4820 - val_decoder_output_loss: 28.4548 - val_classifier_output_loss: 8.2113
# Epoch 18/40
# 60000/60000 [==============================] - 5s 89us/sample - loss: 28.5131 - decoder_output_loss: 27.6368 - classifier_output_loss: 6.1828 - val_loss: 29.3199 - val_decoder_output_loss: 28.3338 - val_classifier_output_loss: 7.8304
# Epoch 19/40
# 60000/60000 [==============================] - 5s 87us/sample - loss: 28.3535 - decoder_output_loss: 27.4885 - classifier_output_loss: 6.1497 - val_loss: 29.2509 - val_decoder_output_loss: 28.2449 - val_classifier_output_loss: 8.1575
# Epoch 20/40
# 60000/60000 [==============================] - 5s 89us/sample - loss: 28.1861 - decoder_output_loss: 27.3425 - classifier_output_loss: 5.9677 - val_loss: 29.1640 - val_decoder_output_loss: 28.1125 - val_classifier_output_loss: 8.2075
# Epoch 21/40
# 60000/60000 [==============================] - 5s 89us/sample - loss: 28.0565 - decoder_output_loss: 27.2273 - classifier_output_loss: 5.8856 - val_loss: 29.2117 - val_decoder_output_loss: 28.1256 - val_classifier_output_loss: 8.2701
# Epoch 22/40
# 60000/60000 [==============================] - 5s 88us/sample - loss: 27.9227 - decoder_output_loss: 27.1073 - classifier_output_loss: 5.8099 - val_loss: 29.0533 - val_decoder_output_loss: 28.0660 - val_classifier_output_loss: 7.9067
# Epoch 23/40
# 60000/60000 [==============================] - 5s 90us/sample - loss: 27.7667 - decoder_output_loss: 26.9602 - classifier_output_loss: 5.7850 - val_loss: 28.9410 - val_decoder_output_loss: 27.9983 - val_classifier_output_loss: 7.9731
# Epoch 24/40
# 60000/60000 [==============================] - 5s 91us/sample - loss: 27.7197 - decoder_output_loss: 26.9134 - classifier_output_loss: 5.8043 - val_loss: 28.8942 - val_decoder_output_loss: 27.8891 - val_classifier_output_loss: 8.0316
# Epoch 25/40
# 60000/60000 [==============================] - 5s 88us/sample - loss: 27.6167 - decoder_output_loss: 26.8248 - classifier_output_loss: 5.7136 - val_loss: 28.8785 - val_decoder_output_loss: 27.8490 - val_classifier_output_loss: 7.8188
# Epoch 26/40
# 60000/60000 [==============================] - 5s 90us/sample - loss: 27.5016 - decoder_output_loss: 26.7177 - classifier_output_loss: 5.6635 - val_loss: 28.7417 - val_decoder_output_loss: 27.7564 - val_classifier_output_loss: 7.5154
# Epoch 27/40
# 60000/60000 [==============================] - 5s 89us/sample - loss: 27.3724 - decoder_output_loss: 26.6106 - classifier_output_loss: 5.5127 - val_loss: 28.7723 - val_decoder_output_loss: 27.7689 - val_classifier_output_loss: 7.9452
# Epoch 28/40
# 60000/60000 [==============================] - 6s 94us/sample - loss: 27.3141 - decoder_output_loss: 26.5517 - classifier_output_loss: 5.5294 - val_loss: 28.7618 - val_decoder_output_loss: 27.8042 - val_classifier_output_loss: 7.8596
# Epoch 29/40
# 60000/60000 [==============================] - 5s 90us/sample - loss: 27.2396 - decoder_output_loss: 26.4819 - classifier_output_loss: 5.5415 - val_loss: 28.7389 - val_decoder_output_loss: 27.7775 - val_classifier_output_loss: 7.5893
# Epoch 30/40
# 60000/60000 [==============================] - 5s 89us/sample - loss: 27.1799 - decoder_output_loss: 26.4308 - classifier_output_loss: 5.4669 - val_loss: 28.6019 - val_decoder_output_loss: 27.6173 - val_classifier_output_loss: 7.3482
# Epoch 31/40
# 60000/60000 [==============================] - 5s 87us/sample - loss: 27.0839 - decoder_output_loss: 26.3396 - classifier_output_loss: 5.4529 - val_loss: 28.5716 - val_decoder_output_loss: 27.5989 - val_classifier_output_loss: 7.8427
# Epoch 32/40
# 60000/60000 [==============================] - 5s 89us/sample - loss: 27.0192 - decoder_output_loss: 26.2891 - classifier_output_loss: 5.3612 - val_loss: 28.5831 - val_decoder_output_loss: 27.6480 - val_classifier_output_loss: 7.7858
# Epoch 33/40
# 60000/60000 [==============================] - 5s 88us/sample - loss: 26.9732 - decoder_output_loss: 26.2415 - classifier_output_loss: 5.4144 - val_loss: 28.4377 - val_decoder_output_loss: 27.4510 - val_classifier_output_loss: 7.9133
# Epoch 34/40
# 60000/60000 [==============================] - 5s 88us/sample - loss: 26.9126 - decoder_output_loss: 26.1892 - classifier_output_loss: 5.3739 - val_loss: 28.5228 - val_decoder_output_loss: 27.5822 - val_classifier_output_loss: 7.7524
# Epoch 35/40
# 60000/60000 [==============================] - 6s 93us/sample - loss: 26.8756 - decoder_output_loss: 26.1519 - classifier_output_loss: 5.4048 - val_loss: 28.4636 - val_decoder_output_loss: 27.4652 - val_classifier_output_loss: 7.9131
# Epoch 36/40
# 60000/60000 [==============================] - 5s 90us/sample - loss: 26.8041 - decoder_output_loss: 26.0862 - classifier_output_loss: 5.3565 - val_loss: 28.4113 - val_decoder_output_loss: 27.3976 - val_classifier_output_loss: 7.8335
# Epoch 37/40
# 60000/60000 [==============================] - 5s 91us/sample - loss: 26.7313 - decoder_output_loss: 26.0221 - classifier_output_loss: 5.2981 - val_loss: 28.3928 - val_decoder_output_loss: 27.4357 - val_classifier_output_loss: 7.5025
# Epoch 38/40
# 60000/60000 [==============================] - 5s 89us/sample - loss: 26.6956 - decoder_output_loss: 25.9834 - classifier_output_loss: 5.3346 - val_loss: 28.3223 - val_decoder_output_loss: 27.3479 - val_classifier_output_loss: 7.3729
# Epoch 39/40
# 60000/60000 [==============================] - 5s 90us/sample - loss: 26.6674 - decoder_output_loss: 25.9663 - classifier_output_loss: 5.2627 - val_loss: 28.2685 - val_decoder_output_loss: 27.3818 - val_classifier_output_loss: 7.4613
# Epoch 40/40
# 60000/60000 [==============================] - 5s 88us/sample - loss: 26.6322 - decoder_output_loss: 25.9286 - classifier_output_loss: 5.3319 - val_loss: 28.3608 - val_decoder_output_loss: 27.3960 - val_classifier_output_loss: 8.0234
