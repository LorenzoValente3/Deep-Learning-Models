# %%
import tensorflow as tf
from tensorflow.python.keras import Input
from tensorflow.python.keras.engine.functional import Functional
from tensorflow.python.keras.engine.keras_tensor import KerasTensor
from tensorflow.python.keras.models import Model, Sequential

import numpy as np
from matplotlib import pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Dense, Lambda

from tensorflow.python.keras.regularizers import l2
from tensorflow.keras import backend as K
tf.compat.v1.disable_eager_execution()

import tensorflow.python.util.deprecation as deprecation
deprecation._PRINT_DEPRECATION_WARNINGS = False

# %% [markdown]
# ## Import the MNIST data class and call it.

# %%
import MNIST_dataset as mnist
data = mnist.MNISTData()

# %% [markdown]
# # Variational Autoencoder using Keras
# The aim of this class is to implement the variational autoencoder and to test it on the MNIST dataset and then build a variational autoencoder that is able to classify MNIST data in its latent dimension with gaussian noise applied to the orignal images.
#
# Code partially adapted from [Keras Documentation](https://keras.io/examples/generative/vae/).

# %%
class VAE:
    """Variational Autencoder Class"""
    def __init__(self, data: mnist.MNISTData, num_classes=10):
        self.x_train = data.x_train
        self.x_test = data.x_test
        self.y_train = data.y_train
        self.y_test = data.y_test

        self.num_classes = num_classes
        self.input_shape = self.x_train[0].shape
        self.input = Input(shape=self.input_shape,name='encoder_input')
        self.latent_dim = 2

        self.encoder = None
        self.encoder_model = None

        self.decoder = None
        self.VAE = None
        self.encoded_mean = None
        self.encoded_var = None
        self.decoder_model=None
        
    def build_encoder(self):
        """Building the encoder architecture for the variational autoencoder. 
        The final encoding dimension is 2. 
        """
        self.encoder = Dense(512, activation='relu')(self.input)
        self.encoder = Dense(64, activation='relu')(self.encoder)
        self.encoded_mean = Dense(self.latent_dim)(self.encoder)
        self.encoded_var = Dense(self.latent_dim)(self.encoder)
        self.encoder = Lambda(self.sampling, output_shape=(self.latent_dim,), name = 'encoder_output')([self.encoded_mean, self.encoded_var])

        #building a model for the encoder in order to be able to predict and plot the latent dimension
        self.encoder_model = Model(self.input, [self.encoded_mean, self.encoded_var, self.encoder], name='encoder')
    
    def build_decoder(self):
        """Building the decoder architecture and storing the output in self.decoder."""
        if self.encoder is None:
            raise RuntimeError("The encoder has to be built before you can build the decoder!")        

        self.decoder = Dense(64, activation='relu')(self.encoder)
        self.decoder = Dense(512, activation='relu')(self.decoder)
        self.decoder = Dense(784, activation='sigmoid', name='decoder_output')(self.decoder)
        
    def build_classifier(self):
        """ Building the classifier architecture, using self.encoder as input."""

        if self.encoder is None:
            raise RuntimeError("The encoder has to be built before you can build the classifier!")
        self.latent_classifier = Dense(self.num_classes, activation='softmax',name='classifier_output')(self.encoder)
        
    def build_vae(self, use_latent_classifier=False):
        """ Building the whole variational autoencoder Model from self.encoder and self.decoder with 
        self.input as input. It is used self.custom_loss as the model loss function.
        """
        if self.encoder is None:
            raise RuntimeError("The encoder has to be built before you can build the autoencoder!")
        if self.decoder is None:
            raise RuntimeError("The decoder has to be built before you can build the autoencoder!")
        
        self.dir()

        if use_latent_classifier:
            if self.latent_classifier is None:
                raise RuntimeError("If you want to use the option with the latent classifier, you have to build it "
                                   "beforehand!")
            self.VAE = Model(self.input, outputs=[self.decoder, self.latent_classifier])
            self.VAE.compile(loss=self.custom_loss(self.encoded_mean, self.encoded_var), loss_weights=[1, 0.1], optimizer='adam', metrics=["accuracy"])
        else:
            self.VAE = Model(self.input, outputs=self.decoder)
            self.VAE.compile(optimizer='adam', loss=self.custom_loss(self.encoded_mean, self.encoded_var))
            self.VAE.summary()

    def sampling(self, args):
        """ Implement the Reparameterization trick. The function returns
         a vector randomly sampled from the latent space.
         # Arguments
        args (tensor): mean and log of variance of Q(z|X)
         # Returns
            z (tensor): sampled latent vector   
        """
        z_mean, z_log_var = args
        batch = K.shape(z_mean)[0]
        dim = K.int_shape(z_mean)[1]
        # we apply the multigaussian noise to every points at once
        epsilon = K.random_normal(shape=(batch, dim))
        return z_mean + K.exp(0.5 * z_log_var) * epsilon
    

    def custom_loss(self, mean, var):
        """Implement the loss function for the variational autoencoder.
        Sort of recepy for tf to how to compute loss function from two values."""
        
        def loss(y_true, y_pred):

            reconstruction_loss = tf.losses.mean_squared_error(y_true, y_pred)*784
            kl_loss = 1. + var - K.square(mean) - K.exp(var)
            kl_loss = K.sum(kl_loss, axis=-1)
            kl_loss *= -0.5
            beta = 1.0*10**-2
            return K.mean(reconstruction_loss + beta*kl_loss)

        return loss
        
        
    def fit_data(self, batch_size=128, epochs=40, use_latent_classifier=False):
        """Write the fit function for the autoencoder. 
        Store the fit history in self.history to be able to plot the fitting scores."""
        
        if use_latent_classifier:
            self.history = self.VAE.fit(self.x_train, [self.x_train, self.y_train],
                                                validation_data=(self.x_test, [self.x_test, self.y_test]),
                                                batch_size=batch_size, epochs=epochs,
                                                shuffle=True,
                                                )
        else:
            self.history = self.VAE.fit(self.x_train, self.x_train, validation_data=(self.x_test, self.x_test),
                                                batch_size=batch_size, epochs=epochs,
                                                shuffle=True,
                                                )
        
        self.history = self.history.history

    def dir(self):
        """Creation of the directories"""
        dir = os.path.join("images")
        if not os.path.exists(dir):
            os.mkdir(dir)
        dir2 = os.path.join("./images/VAE")
        if not os.path.exists(dir2):
            os.mkdir(dir2)
    
    def plot_score(self, use_latent_classifier = False, model_name=None):
        """Plots the scores achieved during the fitting."""
        if use_latent_classifier is False:
            plt.plot(self.history['loss'])
            plt.plot(self.history['val_loss'])
            plt.ylabel('Model Accuracy')
        else:
            plt.plot(self.history['classifier_output_accuracy'])
            plt.plot(self.history['val_classifier_output_accuracy'])
            plt.ylabel('Classifier Accuracy')
            
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Test'], loc='best')
        plt.title('Accuracy of {model_name}'.format(model_name=model_name))
        
        plt.savefig('./images/VAE/Accuracy of {model_name}.png'.format(model_name=model_name))
        
        plt.show()

    def plot_latent_dimension(self, model_name=None):
        """Plots the latent dimension of the autoencoder."""
        prediction = self.encoder_model.predict(self.x_test)
        fig = plt.figure(figsize=(10, 10))
        fig.patch.set_facecolor("white")
        plt.scatter(prediction[2][:, 0], prediction[2][:, 1], c=np.argmax(self.y_test, axis=1) , cmap="Set3")
        plt.colorbar()
        plt.title('Latent space {model_name}'.format(model_name=model_name))
        
        plt.savefig('./images/VAE/Latent dimension of {model_name}.png'.format(model_name=model_name))

        plt.show()

# %%
network = VAE(data)
network.build_encoder()
network.build_decoder()
network.build_vae()
network.fit_data()
network.plot_latent_dimension("Variational Autoencoder without classifier")
network.plot_score(use_latent_classifier=False, model_name="Variational Autoencoder without classifier")
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      [(None, 784)]        0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          401920      encoder_input[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           32832       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 2)            130         dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2)            130         dense_1[0][0]
# __________________________________________________________________________________________________
# encoder_output (Lambda)         (None, 2)            0           dense_2[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           192         encoder_output[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 512)          33280       dense_4[0][0]
# __________________________________________________________________________________________________
# decoder_output (Dense)          (None, 784)          402192      dense_5[0][0]
# ==================================================================================================
# Total params: 870,676
# Trainable params: 870,676
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/40
# 60000/60000 [==============================] - 14s 235us/sample - loss: 46.9653 - val_loss: 38.4104
# Epoch 2/40
# 60000/60000 [==============================] - 14s 225us/sample - loss: 36.9664 - val_loss: 35.8536
# Epoch 3/40
# 60000/60000 [==============================] - 12s 204us/sample - loss: 35.1063 - val_loss: 34.2351
# Epoch 4/40
# 60000/60000 [==============================] - 4s 70us/sample - loss: 33.7869 - val_loss: 33.1043
# Epoch 5/40
# 60000/60000 [==============================] - 4s 68us/sample - loss: 32.7084 - val_loss: 32.1557
# Epoch 6/40
# 60000/60000 [==============================] - 4s 71us/sample - loss: 31.8778 - val_loss: 31.3574
# Epoch 7/40
# 60000/60000 [==============================] - 4s 67us/sample - loss: 31.1863 - val_loss: 31.0283
# Epoch 8/40
# 60000/60000 [==============================] - 4s 64us/sample - loss: 30.6793 - val_loss: 30.5993
# Epoch 9/40
# 60000/60000 [==============================] - 4s 71us/sample - loss: 30.2578 - val_loss: 30.2199
# Epoch 10/40
# 60000/60000 [==============================] - 4s 68us/sample - loss: 29.9368 - val_loss: 29.8657
# Epoch 11/40
# 60000/60000 [==============================] - 4s 69us/sample - loss: 29.6418 - val_loss: 29.8707
# Epoch 12/40
# 60000/60000 [==============================] - 4s 68us/sample - loss: 29.3956 - val_loss: 29.4581
# Epoch 13/40
# 60000/60000 [==============================] - 4s 71us/sample - loss: 29.1153 - val_loss: 29.2642
# Epoch 14/40
# 60000/60000 [==============================] - 4s 72us/sample - loss: 28.9264 - val_loss: 29.1834
# Epoch 15/40
# 60000/60000 [==============================] - 4s 70us/sample - loss: 28.7129 - val_loss: 29.1200
# Epoch 16/40
# 60000/60000 [==============================] - 5s 85us/sample - loss: 28.5462 - val_loss: 28.8445
# Epoch 17/40
# 60000/60000 [==============================] - 7s 109us/sample - loss: 28.3665 - val_loss: 28.6983
# Epoch 18/40
# 60000/60000 [==============================] - 7s 113us/sample - loss: 28.2320 - val_loss: 28.6089
# Epoch 19/40
# 60000/60000 [==============================] - 6s 108us/sample - loss: 28.1192 - val_loss: 28.7118
# Epoch 20/40
# 60000/60000 [==============================] - 6s 105us/sample - loss: 27.9779 - val_loss: 28.5713
# Epoch 21/40
# 60000/60000 [==============================] - 6s 107us/sample - loss: 27.8095 - val_loss: 28.3746
# Epoch 22/40
# 60000/60000 [==============================] - 6s 108us/sample - loss: 27.7824 - val_loss: 28.3601
# Epoch 23/40
# 60000/60000 [==============================] - 6s 107us/sample - loss: 27.6712 - val_loss: 28.2742
# Epoch 24/40
# 60000/60000 [==============================] - 6s 106us/sample - loss: 27.6091 - val_loss: 28.2399
# Epoch 25/40
# 60000/60000 [==============================] - 6s 107us/sample - loss: 27.4996 - val_loss: 28.0583
# Epoch 26/40
# 60000/60000 [==============================] - 7s 110us/sample - loss: 27.3463 - val_loss: 28.0584
# Epoch 27/40
# 60000/60000 [==============================] - 7s 109us/sample - loss: 27.2305 - val_loss: 28.0369
# Epoch 28/40
# 60000/60000 [==============================] - 6s 101us/sample - loss: 27.1887 - val_loss: 27.9821
# Epoch 29/40
# 60000/60000 [==============================] - 5s 76us/sample - loss: 27.1352 - val_loss: 27.9711
# Epoch 30/40
# 60000/60000 [==============================] - 7s 109us/sample - loss: 27.0419 - val_loss: 27.9455
# Epoch 31/40
# 60000/60000 [==============================] - 7s 116us/sample - loss: 27.0403 - val_loss: 27.8468
# Epoch 32/40
# 60000/60000 [==============================] - 7s 109us/sample - loss: 26.9202 - val_loss: 27.8534
# Epoch 33/40
# 60000/60000 [==============================] - 6s 107us/sample - loss: 26.8806 - val_loss: 27.8895
# Epoch 34/40
# 60000/60000 [==============================] - 7s 111us/sample - loss: 26.8302 - val_loss: 27.8843
# Epoch 35/40
# 60000/60000 [==============================] - 7s 115us/sample - loss: 26.7356 - val_loss: 27.8458
# Epoch 36/40
# 60000/60000 [==============================] - 7s 112us/sample - loss: 26.6900 - val_loss: 27.7963
# Epoch 37/40
# 60000/60000 [==============================] - 7s 113us/sample - loss: 26.6774 - val_loss: 27.7451
# Epoch 38/40
# 60000/60000 [==============================] - 7s 112us/sample - loss: 26.5984 - val_loss: 27.6378
# Epoch 39/40
# 60000/60000 [==============================] - 7s 114us/sample - loss: 26.5107 - val_loss: 27.6834
# Epoch 40/40
# 60000/60000 [==============================] - 7s 111us/sample - loss: 26.5129 - val_loss: 27.5789

# %%
network_with_classifier = VAE(data)
network_with_classifier.build_encoder()
network_with_classifier.build_decoder()
network_with_classifier.build_classifier()
network_with_classifier.build_vae(use_latent_classifier=True)
network_with_classifier.fit_data(use_latent_classifier=True)
network_with_classifier.plot_latent_dimension("Variational Autoencoder with classifier")
network_with_classifier.plot_score(use_latent_classifier=True,model_name="Variational Autoencoder with classifier")
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/40
# 60000/60000 [==============================] - 5s 90us/sample - loss: 51.7718 - decoder_output_loss: 45.4530 - classifier_output_loss: 63.1415 - decoder_output_accuracy: 0.0110 - classifier_output_accuracy: 0.3355 - val_loss: 42.2916 - val_decoder_output_loss: 37.5264 - val_classifier_output_loss: 48.1097 - val_decoder_output_accuracy: 0.0131 - val_classifier_output_accuracy: 0.4886
# Epoch 2/40
# 60000/60000 [==============================] - 4s 72us/sample - loss: 40.4582 - decoder_output_loss: 35.9574 - classifier_output_loss: 45.0022 - decoder_output_accuracy: 0.0120 - classifier_output_accuracy: 0.5626 - val_loss: 38.6235 - val_decoder_output_loss: 34.5429 - val_classifier_output_loss: 41.3004 - val_decoder_output_accuracy: 0.0088 - val_classifier_output_accuracy: 0.6167
# Epoch 3/40
# 60000/60000 [==============================] - 5s 75us/sample - loss: 37.7577 - decoder_output_loss: 33.8717 - classifier_output_loss: 38.8499 - decoder_output_accuracy: 0.0098 - classifier_output_accuracy: 0.6398 - val_loss: 36.7961 - val_decoder_output_loss: 33.0986 - val_classifier_output_loss: 36.2286 - val_decoder_output_accuracy: 0.0059 - val_classifier_output_accuracy: 0.6831
# Epoch 4/40
# 60000/60000 [==============================] - 4s 74us/sample - loss: 36.1246 - decoder_output_loss: 32.6379 - classifier_output_loss: 34.8677 - decoder_output_accuracy: 0.0095 - classifier_output_accuracy: 0.6989 - val_loss: 35.4695 - val_decoder_output_loss: 32.2202 - val_classifier_output_loss: 32.7910 - val_decoder_output_accuracy: 0.0099 - val_classifier_output_accuracy: 0.7237
# Epoch 5/40
# 60000/60000 [==============================] - 5s 76us/sample - loss: 34.9641 - decoder_output_loss: 31.8197 - classifier_output_loss: 31.4402 - decoder_output_accuracy: 0.0111 - classifier_output_accuracy: 0.7354 - val_loss: 34.5349 - val_decoder_output_loss: 31.5668 - val_classifier_output_loss: 29.7980 - val_decoder_output_accuracy: 0.0114 - val_classifier_output_accuracy: 0.7635
# Epoch 6/40
# 60000/60000 [==============================] - 4s 74us/sample - loss: 34.0833 - decoder_output_loss: 31.2330 - classifier_output_loss: 28.4978 - decoder_output_accuracy: 0.0121 - classifier_output_accuracy: 0.7704 - val_loss: 33.8330 - val_decoder_output_loss: 31.0824 - val_classifier_output_loss: 27.2524 - val_decoder_output_accuracy: 0.0144 - val_classifier_output_accuracy: 0.7898
# Epoch 7/40
40
# 60000/60000 [==============================] - 4s 73us/sample - loss: 27.5151 - decoder_output_loss: 26.6202 - classifier_output_loss: 8.9459 - decoder_output_accuracy: 0.0165 - classifier_output_accuracy: 0.9506 - val_loss: 29.0601 - val_decoder_output_loss: 28.0436 - val_classifier_output_loss: 10.0918 - val_decoder_output_accuracy: 0.0169 - val_classifier_output_accuracy: 0.9377
# Epoch 33/40
# 60000/60000 [==============================] - 4s 74us/sample - loss: 27.4226 - decoder_output_loss: 26.5452 - classifier_output_loss: 8.7706 - decoder_output_accuracy: 0.0174 - classifier_output_accuracy: 0.9517 - val_loss: 28.9810 - val_decoder_output_loss: 27.9880 - val_classifier_output_loss: 9.8669 - val_decoder_output_accuracy: 0.0144 - val_classifier_output_accuracy: 0.9369
# Epoch 34/40
# 60000/60000 [==============================] - 5s 75us/sample - loss: 27.3673 - decoder_output_loss: 26.5001 - classifier_output_loss: 8.6655 - decoder_output_accuracy: 0.0169 - classifier_output_accuracy: 0.9523 - val_loss: 28.9842 - val_decoder_output_loss: 27.9526 - val_classifier_output_loss: 9.9523 - val_decoder_output_accuracy: 0.0137 - val_classifier_output_accuracy: 0.9367
# Epoch 35/40
# 60000/60000 [==============================] - 4s 74us/sample - loss: 27.2854 - decoder_output_loss: 26.4317 - classifier_output_loss: 8.5401 - decoder_output_accuracy: 0.0167 - classifier_output_accuracy: 0.9527 - val_loss: 28.9121 - val_decoder_output_loss: 27.9530 - val_classifier_output_loss: 9.7802 - val_decoder_output_accuracy: 0.0140 - val_classifier_output_accuracy: 0.9370
# Epoch 36/40
# 60000/60000 [==============================] - 5s 76us/sample - loss: 27.2105 - decoder_output_loss: 26.3665 - classifier_output_loss: 8.4457 - decoder_output_accuracy: 0.0165 - classifier_output_accuracy: 0.9525 - val_loss: 28.9173 - val_decoder_output_loss: 27.9543 - val_classifier_output_loss: 9.5742 - val_decoder_output_accuracy: 0.0127 - val_classifier_output_accuracy: 0.9392
# Epoch 37/40
# 60000/60000 [==============================] - 4s 72us/sample - loss: 27.1458 - decoder_output_loss: 26.3175 - classifier_output_loss: 8.2846 - decoder_output_accuracy: 0.0166 - classifier_output_accuracy: 0.9536 - val_loss: 28.8970 - val_decoder_output_loss: 27.8913 - val_classifier_output_loss: 9.5980 - val_decoder_output_accuracy: 0.0147 - val_classifier_output_accuracy: 0.9387
# Epoch 38/40
# 60000/60000 [==============================] - 4s 73us/sample - loss: 27.0876 - decoder_output_loss: 26.2660 - classifier_output_loss: 8.2158 - decoder_output_accuracy: 0.0167 - classifier_output_accuracy: 0.9536 - val_loss: 28.8986 - val_decoder_output_loss: 27.8927 - val_classifier_output_loss: 9.5390 - val_decoder_output_accuracy: 0.0158 - val_classifier_output_accuracy: 0.9386
# Epoch 39/40
# 60000/60000 [==============================] - 4s 73us/sample - loss: 26.9998 - decoder_output_loss: 26.1907 - classifier_output_loss: 8.0837 - decoder_output_accuracy: 0.0166 - classifier_output_accuracy: 0.9543 - val_loss: 28.7827 - val_decoder_output_loss: 27.8608 - val_classifier_output_loss: 9.3415 - val_decoder_output_accuracy: 0.0177 - val_classifier_output_accuracy: 0.9390
# Epoch 40/40
# 60000/60000 [==============================] - 4s 73us/sample - loss: 26.9475 - decoder_output_loss: 26.1479 - classifier_output_loss: 7.9920 - decoder_output_accuracy: 0.0174 - classifier_output_accuracy: 0.9543 - val_loss: 28.7874 - val_decoder_output_loss: 27.7828 - val_classifier_output_loss: 9.3177 - val_decoder_output_accuracy: 0.0155 - val_classifier_output_accuracy: 0.9392

# %% [markdown]
# ## In this part a test is provided.

# %%
def test_network_empty(network):
    error = 'When you create a network instance all networks should be None and addable by hand later.'
    assert network.encoder is None, error
    assert network.decoder is None, error
    assert network.VAE is None, error

def test_tensor_and_functional(network):
    assert (isinstance(network.encoder, KerasTensor) or isinstance(network.encoder, tf.Tensor)), """
    After building the encoder it must be a keras tensor."""
    assert (isinstance(network.decoder, KerasTensor) or isinstance(network.decoder, tf.Tensor)), """
    After building the decoder it must be a keras tensor."""
    assert isinstance(network.VAE, Functional), """
    After building the encoder it must be a keras Functional."""
    assert (isinstance(network.latent_classifier, KerasTensor) or 
    isinstance(network.latent_classifier, tf.Tensor)), """
    After building the latent_classifier it must be a keras tensor."""

def test_shape(network):
    assert network.decoder.shape[-1] == 784, """
    After building the decoder it must be a keras tensor."""
    assert network.encoder.shape[-1] == 2, """
    After building the encoder it must have shape (None,2), but is
    """ + str(network.encoder.shape)
    assert (isinstance(network.latent_classifier, KerasTensor) or 
    isinstance(network.latent_classifier, tf.Tensor)), """
    After building the latent_classifier it must be a keras tensor."""
    assert network.VAE.input_shape == network.VAE.output_shape

def test_sampling(network):
    samples=[]
    samples_var=[]
    samples_mean=[]
    for _ in range(100):
        prediction = network.encoder_model.predict(network.x_test[0].reshape(1,-1))
        samples.append(prediction[2])
        samples_mean.append(prediction[0])
        samples_var.append(prediction[1])
    x = int(np.isclose(np.array(samples)[:,0][:,0].var(),0, atol=0.00001))+ int(np.isclose(np.array(samples_var)[:,0][:,0].var(),0, atol=0.00001))+int(np.isclose(np.array(samples_mean)[:,0][:,0].var(), 0, atol=0.00001))
    assert x==2, "There should be some variance when sampling from the latent dimension." 

def test_classifier(network, dataset):
    assert network.VAE.input_shape in network.VAE.output_shape
    assert (None, 10) in network.VAE.output_shape
    prediction = network.VAE.predict(dataset.x_test)
    assert (np.all(prediction[1] <= 1) and np.all(prediction[1] >= 0)) and (
        np.all(prediction[0] <= 1) and np.all(prediction[0] >= 0))

# %%
test_data = mnist.MNISTData(data_fraction =1/100)
test_network = VAE(test_data)

test_network_empty(test_network)

test_network = VAE(test_data)
test_network.build_encoder()
test_network.build_decoder()
test_network.build_classifier()
test_network.build_vae()

test_tensor_and_functional(test_network)
test_shape(test_network)
test_sampling(test_network)

test_network.build_vae(use_latent_classifier=True)
test_network.fit_data(epochs=1, use_latent_classifier=True)

test_classifier(test_network, test_data)
# Out:
# Model: "functional_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      [(None, 784)]        0
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 512)          401920      encoder_input[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 64)           32832       dense_12[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 2)            130         dense_13[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 2)            130         dense_13[0][0]
# __________________________________________________________________________________________________
# encoder_output (Lambda)         (None, 2)            0           dense_14[0][0]
#                                                                  dense_15[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 64)           192         encoder_output[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 512)          33280       dense_16[0][0]
# __________________________________________________________________________________________________
# decoder_output (Dense)          (None, 784)          402192      dense_17[0][0]
# ==================================================================================================
# Total params: 870,676
# Trainable params: 870,676
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 600 samples, validate on 100 samples
# 600/600 [==============================] - 0s 187us/sample - loss: 178.0823 - decoder_output_loss: 169.3024 - classifier_output_loss: 74.8475 - decoder_output_accuracy: 0.0050 - classifier_output_accuracy: 0.1000 - val_loss: 141.5087 - val_decoder_output_loss: 132.4577 - val_classifier_output_loss: 90.5098 - val_decoder_output_accuracy: 0.0100 - val_classifier_output_accuracy: 0.1000
