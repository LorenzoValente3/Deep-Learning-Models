# %%
import tensorflow as tf
from tensorflow.python.keras import Input
from tensorflow.python.keras.models import Model
from tensorflow.python.keras.engine.keras_tensor import KerasTensor
from tensorflow.python.keras.engine.functional import Functional
import numpy as np
from matplotlib import pyplot as plt
from tensorflow.keras.layers import Dense
from tensorflow.python.keras.regularizers import l2
import os

# %% [markdown]
# ### Import the MNIST data class and call it.

# %%
import MNIST_dataset as mnist
data = mnist.MNISTData()

# %% [markdown]
# # Autoencoder using Keras
# The aim of this class is to implement a simple autoencoder for the MNIST data and then build an autoencoder that is
# able to classify MNIST data in its latent dimension.
#
# Code partially adapted from [Keras Documentation](https://blog.keras.io/building-autoencoders-in-keras.html).

# %%
class Autoencoder:
    """Autoencoder Class"""

    def __init__(self, data: mnist.MNISTData, num_classes=10):
        self.x_train = data.x_train
        self.x_test = data.x_test
        self.y_train = data.y_train
        self.y_test = data.y_test

        self.num_classes = num_classes
        self.input_shape = self.x_train[0].shape
        self.input = Input(shape=self.input_shape, name='encoder_input')

        self.encoder = None
        self.encoder_model = None
        self.decoder = None
        self.latent_classifier = None
        self.autoencoder = None

        self.history = None

    def build_encoder(self):
        """Build your encoder architecture and store the output in self.encoder. 
        The final encoding dimension is 2."""
        self.encoder = Dense(128,  activation='relu')(self.input)
        self.encoder = Dense(64,  activation='relu')(self.encoder)
        self.encoder = Dense(2,  activation='relu', name = 'encoder_output')(self.encoder)      
        
        #building a model for the encoder in order to be able to predict and plot the latent dimension
        self.encoder_model = Model(self.input, self.encoder, name='encoder')

    def build_decoder(self):
        """Build the decoder architecture."""
        if self.encoder is None:
            raise RuntimeError("The encoder has to be built before you can build the decoder!")
        self.decoder = Dense(64, activation='relu')(self.encoder)
        self.decoder = Dense(128, activation='relu')(self.decoder)
        self.decoder = Dense(784,activation='sigmoid', name='ecoder_output')(self.decoder)

    def build_classifier(self):
        """ Building the classifier architecture."""
        if self.encoder is None:
            raise RuntimeError("The encoder has to be built before you can build the classifier!")
        self.latent_classifier = Dense(self.num_classes, activation='softmax', name='classifier_output')(self.encoder)

    def build_autoencoder(self, use_latent_classifier=False):
        """ Build the whole autoencoder Model from self.encoder and self.decoder."""
        if self.encoder is None:
            raise RuntimeError("The encoder has to be built before you can build the autoencoder!")
        if self.decoder is None:
            raise RuntimeError("The decoder has to be built before you can build the autoencoder!")
        
        self.dir()
        
        if use_latent_classifier:
            if self.latent_classifier is None:
                raise RuntimeError("If you want to use the option with the latent classifier, you have to build it "
                                   "beforehand!")
            self.autoencoder = Model(self.input, outputs=[self.decoder, self.latent_classifier])
            self.autoencoder.compile(loss=['mse', 'categorical_crossentropy'], loss_weights=[1, 0.1], optimizer='adam',
                                     metrics="accuracy")
        else:
            self.autoencoder = Model(self.input, outputs=self.decoder, name = 'autoencoder')
            self.autoencoder.compile(loss='mse', optimizer='adam')
        
        self.autoencoder.summary()

    def fit_data(self, batch_size=256, epochs=40, use_latent_classifier=False):
        """Write the fit function for the autoencoder. 
        Storing the fit history in self.history to be able to plot the fitting scores."""
        if use_latent_classifier:
            self.history = self.autoencoder.fit(self.x_train, [self.x_train, self.y_train],
                                                validation_data=(self.x_test, [self.x_test, self.y_test]),
                                                batch_size=batch_size, epochs=epochs,
                                                shuffle=True,
                                                )
        else:
            self.history = self.autoencoder.fit(self.x_train, self.x_train,
                                                validation_data=(self.x_test, self.x_test),
                                                batch_size=batch_size, epochs=epochs,
                                                shuffle=True,
                                                )

        self.history = self.history.history

    def dir(self):
        """Creation of the folders path to store the results."""
        dir = os.path.join("images")
        if not os.path.exists(dir):
            os.mkdir(dir)
        dir2 = os.path.join("./images/AE")
        if not os.path.exists(dir2):
            os.mkdir(dir2)
    
    def plot_score(self, use_latent_classifier = False, model_name=None):
        """Plots the scores achieved during the fitting."""
        if use_latent_classifier is False:
            plt.plot(self.history['loss'])
            plt.plot(self.history['val_loss'])
            plt.ylabel('Model Accuracy')
        else:
            plt.plot(self.history['classifier_output_accuracy'])
            plt.plot(self.history['val_classifier_output_accuracy'])
            plt.ylabel('Classifier Accuracy')
        
        plt.xlabel('Epoch')        
        plt.legend(['Train', 'Test'], loc='best')
        plt.title('Accuracy of {model_name}'.format(model_name=model_name))
        
        plt.savefig('./images/AE/Accuracy of {model_name}.png'.format(model_name=model_name))
        
        plt.show()

    def plot_latent_dimension(self, model_name = None):
        """Plots the latent dimension of the autoencoder."""
        prediction = self.encoder_model.predict(self.x_test)
        fig = plt.figure(figsize=(10, 10))
        fig.patch.set_facecolor("white")
        plt.scatter(prediction[:, 0], prediction[:, 1], c=np.argmax(self.y_test, axis=1), cmap="Set3")
        plt.colorbar()
        plt.title('Latent space {model_name}'.format(model_name=model_name))


        plt.savefig('./images/AE/Latent dimension of {model_name}.png'.format(model_name=model_name))

        plt.show()

    def plot_reco(self, use_latent_classifier = False):
        """Plotting reconstructed images"""
        
        n = 6
        plt.figure(figsize=(10, 3))
        reco_imgs = self.autoencoder.predict(self.x_test)
        
        if use_latent_classifier :
            raise RuntimeError("You are considering the autoencoder with classifier!")
        else:
        
            for i in range(n):
                # Display original MNIST
                ax = plt.subplot(2, n, i + 1)
                plt.imshow(self.x_test[i].reshape(28,28), cmap='gray_r')
                ax.get_xaxis().set_visible(False)
                ax.get_yaxis().set_visible(False)

                # Display reconstructed MNIST            
                ax = plt.subplot(2, n, i + n + 1)
                plt.imshow(reco_imgs[i].reshape(28,28), cmap='gray_r')
                ax.get_xaxis().set_visible(False)
                ax.get_yaxis().set_visible(False)
            plt.savefig('./images/AE/reconstructed images.png')
            plt.show()

# %% [markdown]
# It is built the standard autoencoder, *without classifier* here, and the MNIST data class called before is used.
# The model is fitted and adequate plots are reproduced,
# as well as the comparison between orginal MNIST dataset and reconstructed images.

# %%
network = Autoencoder(data)
network.build_encoder()
network.build_decoder()
network.build_autoencoder()
network.fit_data()
network.plot_latent_dimension("Autoencoder without classifier")
network.plot_reco()
network.plot_score(use_latent_classifier=False, model_name="Autoencoder without classifier")
# Out:
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   [(None, 784)]             0
# _________________________________________________________________
# dense_48 (Dense)             (None, 128)               100480
# _________________________________________________________________
# dense_49 (Dense)             (None, 64)                8256
# _________________________________________________________________
# encoder_output (Dense)       (None, 2)                 130
# _________________________________________________________________
# dense_50 (Dense)             (None, 64)                192
# _________________________________________________________________
# dense_51 (Dense)             (None, 128)               8320
# _________________________________________________________________
# ecoder_output (Dense)        (None, 784)               101136
# =================================================================
# Total params: 218,514
# Trainable params: 218,514
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0775 - val_loss: 0.0648
# Epoch 2/40
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0636 - val_loss: 0.0627
# Epoch 3/40
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0568 - val_loss: 0.0528
# Epoch 4/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0519 - val_loss: 0.0508
# Epoch 5/40
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0498 - val_loss: 0.0488
# Epoch 6/40
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0475 - val_loss: 0.0463
# Epoch 7/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0457 - val_loss: 0.0451
# Epoch 8/40
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0447 - val_loss: 0.0442
# Epoch 9/40
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0438 - val_loss: 0.0436
# Epoch 10/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0431 - val_loss: 0.0430
# Epoch 11/40
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0426 - val_loss: 0.0425
# Epoch 12/40
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0421 - val_loss: 0.0421
# Epoch 13/40
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0417 - val_loss: 0.0418
# Epoch 14/40
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0414 - val_loss: 0.0416
# Epoch 15/40
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0411 - val_loss: 0.0414
# Epoch 16/40
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0409 - val_loss: 0.0412
# Epoch 17/40
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0407 - val_loss: 0.0411
# Epoch 18/40
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0405 - val_loss: 0.0408
# Epoch 19/40
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0403 - val_loss: 0.0407
# Epoch 20/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0401 - val_loss: 0.0406
# Epoch 21/40
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0399 - val_loss: 0.0405
# Epoch 22/40
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0398 - val_loss: 0.0403
# Epoch 23/40
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0396 - val_loss: 0.0402
# Epoch 24/40
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0395 - val_loss: 0.0400
# Epoch 25/40
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0394 - val_loss: 0.0399
# Epoch 26/40
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0392 - val_loss: 0.0399
# Epoch 27/40
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0391 - val_loss: 0.0397
# Epoch 28/40
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0390 - val_loss: 0.0397
# Epoch 29/40
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0389 - val_loss: 0.0396
# Epoch 30/40
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0388 - val_loss: 0.0395
# Epoch 31/40
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0387 - val_loss: 0.0393
# Epoch 32/40
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0386 - val_loss: 0.0393
# Epoch 33/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0385 - val_loss: 0.0392
# Epoch 34/40
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0384 - val_loss: 0.0392
# Epoch 35/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0383 - val_loss: 0.0391
# Epoch 36/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0382 - val_loss: 0.0390
# Epoch 37/40
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0381 - val_loss: 0.0390
# Epoch 38/40
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0381 - val_loss: 0.0390
# Epoch 39/40
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0380 - val_loss: 0.0388
# Epoch 40/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0379 - val_loss: 0.0388

# %% [markdown]
# Repeating the same procedure for the autoencoder with classifier.

# %%
network_with_classifier = Autoencoder(data)
network_with_classifier.build_encoder()
network_with_classifier.build_decoder()
network_with_classifier.build_classifier()
network_with_classifier.build_autoencoder(use_latent_classifier=True)
network_with_classifier.fit_data(use_latent_classifier=True)
network_with_classifier.plot_latent_dimension("Autoencoder with classifier")
network_with_classifier.plot_score(use_latent_classifier=True , model_name="Autoencoder with classifier")
# Out:
# Model: "functional_15"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      [(None, 784)]        0
# __________________________________________________________________________________________________
# dense_56 (Dense)                (None, 128)          100480      encoder_input[0][0]
# __________________________________________________________________________________________________
# dense_57 (Dense)                (None, 64)           8256        dense_56[0][0]
# __________________________________________________________________________________________________
# encoder_output (Dense)          (None, 2)            130         dense_57[0][0]
# __________________________________________________________________________________________________
# dense_58 (Dense)                (None, 64)           192         encoder_output[0][0]
# __________________________________________________________________________________________________
# dense_59 (Dense)                (None, 128)          8320        dense_58[0][0]
# __________________________________________________________________________________________________
# ecoder_output (Dense)           (None, 784)          101136      dense_59[0][0]
# __________________________________________________________________________________________________
# classifier_output (Dense)       (None, 10)           30          encoder_output[0][0]
# ==================================================================================================
# Total params: 218,544
# Trainable params: 218,544
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/40
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2486 - ecoder_output_loss: 0.0820 - classifier_output_loss: 1.6668 - ecoder_output_accuracy: 0.0115 - classifier_output_accuracy: 0.3145 - val_loss: 0.1993 - val_ecoder_output_loss: 0.0633 - val_classifier_output_loss: 1.3601 - val_ecoder_output_accuracy: 0.0091 - val_classifier_output_accuracy: 0.4796
# Epoch 2/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1816 - ecoder_output_loss: 0.0622 - classifier_output_loss: 1.1936 - ecoder_output_accuracy: 0.0100 - classifier_output_accuracy: 0.5284 - val_loss: 0.1672 - val_ecoder_output_loss: 0.0611 - val_classifier_output_loss: 1.0613 - val_ecoder_output_accuracy: 0.0098 - val_classifier_output_accuracy: 0.6530
# Epoch 3/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1530 - ecoder_output_loss: 0.0596 - classifier_output_loss: 0.9340 - ecoder_output_accuracy: 0.0088 - classifier_output_accuracy: 0.7040 - val_loss: 0.1415 - val_ecoder_output_loss: 0.0575 - val_classifier_output_loss: 0.8400 - val_ecoder_output_accuracy: 0.0086 - val_classifier_output_accuracy: 0.7352
# Epoch 4/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1303 - ecoder_output_loss: 0.0564 - classifier_output_loss: 0.7388 - ecoder_output_accuracy: 0.0072 - classifier_output_accuracy: 0.7880 - val_loss: 0.1279 - val_ecoder_output_loss: 0.0548 - val_classifier_output_loss: 0.7314 - val_ecoder_output_accuracy: 0.0066 - val_classifier_output_accuracy: 0.8359
# Epoch 5/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1183 - ecoder_output_loss: 0.0549 - classifier_output_loss: 0.6345 - ecoder_output_accuracy: 0.0056 - classifier_output_accuracy: 0.8516 - val_loss: 0.1193 - val_ecoder_output_loss: 0.0538 - val_classifier_output_loss: 0.6551 - val_ecoder_output_accuracy: 0.0066 - val_classifier_output_accuracy: 0.8595
# Epoch 6/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1076 - ecoder_output_loss: 0.0541 - classifier_output_loss: 0.5351 - ecoder_output_accuracy: 0.0058 - classifier_output_accuracy: 0.9091 - val_loss: 0.1086 - val_ecoder_output_loss: 0.0532 - val_classifier_output_loss: 0.5543 - val_ecoder_output_accuracy: 0.0064 - val_classifier_output_accuracy: 0.9269
# Epoch 7/40
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0976 - ecoder_output_loss: 0.0533 - classifier_output_loss: 0.4438 - ecoder_output_accuracy: 0.0060 - classifier_output_accuracy: 0.9396 - val_loss: 0.1031 - val_ecoder_output_loss: 0.0526 - val_classifier_output_loss: 0.5046 - val_ecoder_output_accuracy: 0.0070 - val_classifier_output_accuracy: 0.9365
# Epoch 8/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0914 - ecoder_output_loss: 0.0527 - classifier_output_loss: 0.3867 - ecoder_output_accuracy: 0.0066 - classifier_output_accuracy: 0.9452 - val_loss: 0.0988 - val_ecoder_output_loss: 0.0520 - val_classifier_output_loss: 0.4689 - val_ecoder_output_accuracy: 0.0070 - val_classifier_output_accuracy: 0.9385
# Epoch 9/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0857 - ecoder_output_loss: 0.0520 - classifier_output_loss: 0.3371 - ecoder_output_accuracy: 0.0095 - classifier_output_accuracy: 0.9509 - val_loss: 0.0975 - val_ecoder_output_loss: 0.0513 - val_classifier_output_loss: 0.4621 - val_ecoder_output_accuracy: 0.0117 - val_classifier_output_accuracy: 0.9374
# Epoch 10/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0816 - ecoder_output_loss: 0.0515 - classifier_output_loss: 0.3011 - ecoder_output_accuracy: 0.0127 - classifier_output_accuracy: 0.9541 - val_loss: 0.0945 - val_ecoder_output_loss: 0.0508 - val_classifier_output_loss: 0.4364 - val_ecoder_output_accuracy: 0.0144 - val_classifier_output_accuracy: 0.9411
# Epoch 11/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0773 - ecoder_output_loss: 0.0510 - classifier_output_loss: 0.2633 - ecoder_output_accuracy: 0.0100 - classifier_output_accuracy: 0.9582 - val_loss: 0.0912 - val_ecoder_output_loss: 0.0502 - val_classifier_output_loss: 0.4103 - val_ecoder_output_accuracy: 0.0108 - val_classifier_output_accuracy: 0.9443
# Epoch 12/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0736 - ecoder_output_loss: 0.0505 - classifier_output_loss: 0.2305 - ecoder_output_accuracy: 0.0095 - classifier_output_accuracy: 0.9631 - val_loss: 0.0888 - val_ecoder_output_loss: 0.0499 - val_classifier_output_loss: 0.3893 - val_ecoder_output_accuracy: 0.0088 - val_classifier_output_accuracy: 0.9462
# Epoch 13/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0705 - ecoder_output_loss: 0.0501 - classifier_output_loss: 0.2043 - ecoder_output_accuracy: 0.0090 - classifier_output_accuracy: 0.9662 - val_loss: 0.0892 - val_ecoder_output_loss: 0.0494 - val_classifier_output_loss: 0.3983 - val_ecoder_output_accuracy: 0.0091 - val_classifier_output_accuracy: 0.9473
# Epoch 14/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0677 - ecoder_output_loss: 0.0498 - classifier_output_loss: 0.1799 - ecoder_output_accuracy: 0.0096 - classifier_output_accuracy: 0.9695 - val_loss: 0.0870 - val_ecoder_output_loss: 0.0492 - val_classifier_output_loss: 0.3774 - val_ecoder_output_accuracy: 0.0095 - val_classifier_output_accuracy: 0.9486
# Epoch 15/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0654 - ecoder_output_loss: 0.0494 - classifier_output_loss: 0.1605 - ecoder_output_accuracy: 0.0093 - classifier_output_accuracy: 0.9726 - val_loss: 0.0903 - val_ecoder_output_loss: 0.0488 - val_classifier_output_loss: 0.4146 - val_ecoder_output_accuracy: 0.0119 - val_classifier_output_accuracy: 0.9499
# Epoch 16/40
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0636 - ecoder_output_loss: 0.0491 - classifier_output_loss: 0.1446 - ecoder_output_accuracy: 0.0102 - classifier_output_accuracy: 0.9746 - val_loss: 0.0870 - val_ecoder_output_loss: 0.0485 - val_classifier_output_loss: 0.3851 - val_ecoder_output_accuracy: 0.0092 - val_classifier_output_accuracy: 0.9512
# Epoch 17/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0620 - ecoder_output_loss: 0.0488 - classifier_output_loss: 0.1315 - ecoder_output_accuracy: 0.0117 - classifier_output_accuracy: 0.9760 - val_loss: 0.0914 - val_ecoder_output_loss: 0.0483 - val_classifier_output_loss: 0.4311 - val_ecoder_output_accuracy: 0.0129 - val_classifier_output_accuracy: 0.9499
# Epoch 18/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0606 - ecoder_output_loss: 0.0485 - classifier_output_loss: 0.1208 - ecoder_output_accuracy: 0.0124 - classifier_output_accuracy: 0.9780 - val_loss: 0.0870 - val_ecoder_output_loss: 0.0484 - val_classifier_output_loss: 0.3856 - val_ecoder_output_accuracy: 0.0076 - val_classifier_output_accuracy: 0.9512
# Epoch 19/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0594 - ecoder_output_loss: 0.0482 - classifier_output_loss: 0.1114 - ecoder_output_accuracy: 0.0125 - classifier_output_accuracy: 0.9794 - val_loss: 0.0888 - val_ecoder_output_loss: 0.0480 - val_classifier_output_loss: 0.4085 - val_ecoder_output_accuracy: 0.0125 - val_classifier_output_accuracy: 0.9513
# Epoch 20/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0584 - ecoder_output_loss: 0.0480 - classifier_output_loss: 0.1042 - ecoder_output_accuracy: 0.0141 - classifier_output_accuracy: 0.9797 - val_loss: 0.0912 - val_ecoder_output_loss: 0.0476 - val_classifier_output_loss: 0.4355 - val_ecoder_output_accuracy: 0.0137 - val_classifier_output_accuracy: 0.9537
# Epoch 21/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0569 - ecoder_output_loss: 0.0477 - classifier_output_loss: 0.0926 - ecoder_output_accuracy: 0.0139 - classifier_output_accuracy: 0.9822 - val_loss: 0.0899 - val_ecoder_output_loss: 0.0472 - val_classifier_output_loss: 0.4274 - val_ecoder_output_accuracy: 0.0160 - val_classifier_output_accuracy: 0.9552
# Epoch 22/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0560 - ecoder_output_loss: 0.0474 - classifier_output_loss: 0.0857 - ecoder_output_accuracy: 0.0141 - classifier_output_accuracy: 0.9841 - val_loss: 0.0919 - val_ecoder_output_loss: 0.0475 - val_classifier_output_loss: 0.4448 - val_ecoder_output_accuracy: 0.0146 - val_classifier_output_accuracy: 0.9559
# Epoch 23/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0555 - ecoder_output_loss: 0.0473 - classifier_output_loss: 0.0825 - ecoder_output_accuracy: 0.0146 - classifier_output_accuracy: 0.9842 - val_loss: 0.0914 - val_ecoder_output_loss: 0.0470 - val_classifier_output_loss: 0.4445 - val_ecoder_output_accuracy: 0.0118 - val_classifier_output_accuracy: 0.9555
# Epoch 24/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0547 - ecoder_output_loss: 0.0470 - classifier_output_loss: 0.0776 - ecoder_output_accuracy: 0.0153 - classifier_output_accuracy: 0.9852 - val_loss: 0.0932 - val_ecoder_output_loss: 0.0468 - val_classifier_output_loss: 0.4644 - val_ecoder_output_accuracy: 0.0117 - val_classifier_output_accuracy: 0.9537
# Epoch 25/40
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0540 - ecoder_output_loss: 0.0467 - classifier_output_loss: 0.0729 - ecoder_output_accuracy: 0.0157 - classifier_output_accuracy: 0.9857 - val_loss: 0.0932 - val_ecoder_output_loss: 0.0464 - val_classifier_output_loss: 0.4677 - val_ecoder_output_accuracy: 0.0128 - val_classifier_output_accuracy: 0.9567
# Epoch 26/40
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0531 - ecoder_output_loss: 0.0465 - classifier_output_loss: 0.0659 - ecoder_output_accuracy: 0.0150 - classifier_output_accuracy: 0.9872 - val_loss: 0.0943 - val_ecoder_output_loss: 0.0462 - val_classifier_output_loss: 0.4808 - val_ecoder_output_accuracy: 0.0118 - val_classifier_output_accuracy: 0.9551
# Epoch 27/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0521 - ecoder_output_loss: 0.0462 - classifier_output_loss: 0.0592 - ecoder_output_accuracy: 0.0158 - classifier_output_accuracy: 0.9888 - val_loss: 0.0943 - val_ecoder_output_loss: 0.0460 - val_classifier_output_loss: 0.4829 - val_ecoder_output_accuracy: 0.0146 - val_classifier_output_accuracy: 0.9572
# Epoch 28/40
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0516 - ecoder_output_loss: 0.0460 - classifier_output_loss: 0.0564 - ecoder_output_accuracy: 0.0153 - classifier_output_accuracy: 0.9891 - val_loss: 0.0930 - val_ecoder_output_loss: 0.0459 - val_classifier_output_loss: 0.4716 - val_ecoder_output_accuracy: 0.0136 - val_classifier_output_accuracy: 0.9571
# Epoch 29/40
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0512 - ecoder_output_loss: 0.0458 - classifier_output_loss: 0.0542 - ecoder_output_accuracy: 0.0151 - classifier_output_accuracy: 0.9896 - val_loss: 0.0942 - val_ecoder_output_loss: 0.0457 - val_classifier_output_loss: 0.4855 - val_ecoder_output_accuracy: 0.0128 - val_classifier_output_accuracy: 0.9564
# Epoch 30/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0513 - ecoder_output_loss: 0.0456 - classifier_output_loss: 0.0570 - ecoder_output_accuracy: 0.0149 - classifier_output_accuracy: 0.9884 - val_loss: 0.0940 - val_ecoder_output_loss: 0.0457 - val_classifier_output_loss: 0.4827 - val_ecoder_output_accuracy: 0.0137 - val_classifier_output_accuracy: 0.9565
# Epoch 31/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0508 - ecoder_output_loss: 0.0455 - classifier_output_loss: 0.0533 - ecoder_output_accuracy: 0.0149 - classifier_output_accuracy: 0.9891 - val_loss: 0.0940 - val_ecoder_output_loss: 0.0454 - val_classifier_output_loss: 0.4857 - val_ecoder_output_accuracy: 0.0125 - val_classifier_output_accuracy: 0.9563
# Epoch 32/40
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0504 - ecoder_output_loss: 0.0453 - classifier_output_loss: 0.0503 - ecoder_output_accuracy: 0.0153 - classifier_output_accuracy: 0.9898 - val_loss: 0.0954 - val_ecoder_output_loss: 0.0453 - val_classifier_output_loss: 0.5010 - val_ecoder_output_accuracy: 0.0124 - val_classifier_output_accuracy: 0.9588
# Epoch 33/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0497 - ecoder_output_loss: 0.0451 - classifier_output_loss: 0.0468 - ecoder_output_accuracy: 0.0150 - classifier_output_accuracy: 0.9908 - val_loss: 0.0961 - val_ecoder_output_loss: 0.0450 - val_classifier_output_loss: 0.5115 - val_ecoder_output_accuracy: 0.0143 - val_classifier_output_accuracy: 0.9571
# Epoch 34/40
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0493 - ecoder_output_loss: 0.0449 - classifier_output_loss: 0.0443 - ecoder_output_accuracy: 0.0160 - classifier_output_accuracy: 0.9911 - val_loss: 0.0932 - val_ecoder_output_loss: 0.0451 - val_classifier_output_loss: 0.4814 - val_ecoder_output_accuracy: 0.0132 - val_classifier_output_accuracy: 0.9572
# Epoch 35/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0490 - ecoder_output_loss: 0.0447 - classifier_output_loss: 0.0431 - ecoder_output_accuracy: 0.0158 - classifier_output_accuracy: 0.9912 - val_loss: 0.0970 - val_ecoder_output_loss: 0.0449 - val_classifier_output_loss: 0.5210 - val_ecoder_output_accuracy: 0.0157 - val_classifier_output_accuracy: 0.9556
# Epoch 36/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0486 - ecoder_output_loss: 0.0445 - classifier_output_loss: 0.0406 - ecoder_output_accuracy: 0.0165 - classifier_output_accuracy: 0.9917 - val_loss: 0.0960 - val_ecoder_output_loss: 0.0448 - val_classifier_output_loss: 0.5121 - val_ecoder_output_accuracy: 0.0141 - val_classifier_output_accuracy: 0.9596
# Epoch 37/40
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0484 - ecoder_output_loss: 0.0444 - classifier_output_loss: 0.0402 - ecoder_output_accuracy: 0.0158 - classifier_output_accuracy: 0.9917 - val_loss: 0.1027 - val_ecoder_output_loss: 0.0446 - val_classifier_output_loss: 0.5810 - val_ecoder_output_accuracy: 0.0117 - val_classifier_output_accuracy: 0.9559
# Epoch 38/40
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0481 - ecoder_output_loss: 0.0443 - classifier_output_loss: 0.0387 - ecoder_output_accuracy: 0.0156 - classifier_output_accuracy: 0.9923 - val_loss: 0.1015 - val_ecoder_output_loss: 0.0445 - val_classifier_output_loss: 0.5702 - val_ecoder_output_accuracy: 0.0146 - val_classifier_output_accuracy: 0.9599
# Epoch 39/40
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0478 - ecoder_output_loss: 0.0441 - classifier_output_loss: 0.0377 - ecoder_output_accuracy: 0.0168 - classifier_output_accuracy: 0.9923 - val_loss: 0.1050 - val_ecoder_output_loss: 0.0441 - val_classifier_output_loss: 0.6095 - val_ecoder_output_accuracy: 0.0146 - val_classifier_output_accuracy: 0.9591
# Epoch 40/40
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0485 - ecoder_output_loss: 0.0442 - classifier_output_loss: 0.0427 - ecoder_output_accuracy: 0.0159 - classifier_output_accuracy: 0.9917 - val_loss: 0.1008 - val_ecoder_output_loss: 0.0441 - val_classifier_output_loss: 0.5664 - val_ecoder_output_accuracy: 0.0144 - val_classifier_output_accuracy: 0.9571

# %% [markdown]
# ## In this part a test is provided.

# %%
def test_network_empty(network):
    error = 'When you create a network instance all networks should be None and addable by hand later.'
    assert network.encoder is None, error
    assert network.decoder is None, error
    assert network.latent_classifier is None, error
    assert network.autoencoder is None, error

def test_tensor_and_functional(network):
    assert (isinstance(network.encoder, KerasTensor) or isinstance(network.encoder, tf.Tensor)), """
    After building the encoder it must be a keras tensor."""
    assert (isinstance(network.decoder, KerasTensor) or isinstance(network.decoder, tf.Tensor)), """
    After building the decoder it must be a keras tensor."""
    assert (isinstance(network.latent_classifier, KerasTensor) or 
    isinstance(network.latent_classifier, tf.Tensor)), """
    After building the latent_classifier it must be a keras tensor."""
    assert isinstance(network.autoencoder, Functional), """
    After building the encoder it must be a keras Functional."""

def test_shape(network):
    assert network.decoder.shape[-1] == 784, """
    After building the decoder it musthave shape (None, 784)."""
    assert network.encoder.shape[-1] == 2, """
    After building the encoder it must have shape (None,2), but is
    """ + str(network.encoder.shape)
    assert network.latent_classifier.shape[-1] == 10, """
    After building the latent_classifier it must be a keras tensor."""
    assert network.autoencoder.input_shape == network.autoencoder.output_shape

def test_classifier(network, dataset):
    assert network.autoencoder.input_shape in network.autoencoder.output_shape
    assert (None, 10) in network.autoencoder.output_shape
    prediction = network.autoencoder.predict(dataset.x_test)
    assert (np.all(prediction[1] <= 1) and np.all(prediction[1] >= 0)) and (
        np.all(prediction[0] <= 1) and np.all(prediction[0] >= 0))

# %%
test_data = mnist.MNISTData(data_fraction=1/100)
test_network = Autoencoder(test_data)

test_network_empty(test_network)

test_network.build_encoder()
test_network.build_decoder()
test_network.build_classifier()
test_network.build_autoencoder()

test_tensor_and_functional(test_network)
test_shape(test_network)

test_network.build_autoencoder(use_latent_classifier=True)
test_network.fit_data(epochs=1, use_latent_classifier=True)

test_classifier(test_network, test_data)
# Out:
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   [(None, 784)]             0
# _________________________________________________________________
# dense_44 (Dense)             (None, 128)               100480
# _________________________________________________________________
# dense_45 (Dense)             (None, 64)                8256
# _________________________________________________________________
# encoder_output (Dense)       (None, 2)                 130
# _________________________________________________________________
# dense_46 (Dense)             (None, 64)                192
# _________________________________________________________________
# dense_47 (Dense)             (None, 128)               8320
# _________________________________________________________________
# ecoder_output (Dense)        (None, 784)               101136
# =================================================================
# Total params: 218,514
# Trainable params: 218,514
# Non-trainable params: 0
# _________________________________________________________________
# Model: "functional_11"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      [(None, 784)]        0
# __________________________________________________________________________________________________
# dense_44 (Dense)                (None, 128)          100480      encoder_input[0][0]
# __________________________________________________________________________________________________
# dense_45 (Dense)                (None, 64)           8256        dense_44[0][0]
# __________________________________________________________________________________________________
# encoder_output (Dense)          (None, 2)            130         dense_45[0][0]
# __________________________________________________________________________________________________
# dense_46 (Dense)                (None, 64)           192         encoder_output[0][0]
# __________________________________________________________________________________________________
# dense_47 (Dense)                (None, 128)          8320        dense_46[0][0]
# __________________________________________________________________________________________________
# ecoder_output (Dense)           (None, 784)          101136      dense_47[0][0]
# __________________________________________________________________________________________________
# classifier_output (Dense)       (None, 10)           30          encoder_output[0][0]
# ==================================================================================================
# Total params: 218,544
# Trainable params: 218,544
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 3/3 [==============================] - 0s 163ms/step - loss: 0.4601 - ecoder_output_loss: 0.2311 - classifier_output_loss: 2.2896 - ecoder_output_accuracy: 0.0033 - classifier_output_accuracy: 0.1233 - val_loss: 0.4572 - val_ecoder_output_loss: 0.2305 - val_classifier_output_loss: 2.2674 - val_ecoder_output_accuracy: 0.0200 - val_classifier_output_accuracy: 0.2100
