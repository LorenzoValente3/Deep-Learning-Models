# %%
import tensorflow as tf
from tensorflow.python.keras import Input
from tensorflow.python.keras.engine.functional import Functional
from tensorflow.python.keras.engine.keras_tensor import KerasTensor
from tensorflow.python.keras.models import Model, Sequential

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)

import numpy as np
from matplotlib import pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Dense, Lambda, Layer, Add, Multiply
from tensorflow.keras import layers

from tensorflow.python.keras.utils.np_utils import to_categorical
from tensorflow.python.keras.regularizers import l2
from tensorflow.keras import backend as K
tf.compat.v1.disable_eager_execution()


from scipy.stats import norm

import tensorflow.python.util.deprecation as deprecation
deprecation._PRINT_DEPRECATION_WARNINGS = False

# %% [markdown]
# ## Import the MNIST data class and call it.

# %%
import MNIST_dataset as mnist
data = mnist.MNISTData()

# %% [markdown]
# # Variational Autoencoder using Keras
# The aim of this class is to implement the variational autoencoder and to test it on the MNIST dataset and then build a variational autoencoder that is able to classify MNIST data in its latent dimension with gaussian noise applied to the orignal images.
#
# Code partially adapted from [Keras Documentation](https://keras.io/examples/generative/vae/).

# %%
class VAE:
    """Variational Autencoder Class"""
    def __init__(self, data: mnist.MNISTData, num_classes=10):
        self.x_train = data.x_train
        self.x_test = data.x_test
        self.y_train = data.y_train
        self.y_test = data.y_test

        self.num_classes = num_classes
        self.input_shape = self.x_train[0].shape
        self.input = Input(shape=self.input_shape,name='encoder_input')
        self.latent_dim = 2

        self.encoder = None
        self.encoder_model = None

        self.decoder = None
        self.VAE = None
        self.encoded_mean = None
        self.encoded_var = None
        self.decoder_model=None
        
    def build_encoder(self):
        """Building the encoder architecture for the variational autoencoder. 
        The final encoding dimension is 2. 
        """
        self.encoder = Dense(512, activation='relu')(self.input)
        self.encoder = Dense(64, activation='relu')(self.encoder)
        self.encoded_mean = Dense(self.latent_dim)(self.encoder)
        self.encoded_var = Dense(self.latent_dim)(self.encoder)
        self.encoder = Lambda(self.sampling, output_shape=(self.latent_dim,), name = 'encoder_output')([self.encoded_mean, self.encoded_var])

        #building a model for the encoder in order to be able to predict and plot the latent dimension
        self.encoder_model = Model(self.input, [self.encoded_mean, self.encoded_var, self.encoder], name='encoder')
    
    def build_decoder(self):
        """Building the decoder architecture and storing the output in self.decoder."""
        if self.encoder is None:
            raise RuntimeError("The encoder has to be built before you can build the decoder!")        

        self.decoder = Dense(64, activation='relu')(self.encoder)
        self.decoder = Dense(512, activation='relu')(self.decoder)
        self.decoder = Dense(784, activation='sigmoid', name='decoder_output')(self.decoder)
        
    def build_classifier(self):
        """ Building the classifier architecture, using self.encoder as input."""

        if self.encoder is None:
            raise RuntimeError("The encoder has to be built before you can build the classifier!")
        if self.decoder is None:
            raise RuntimeError("The decoder has to be built before you can build the autoencoder!")
        self.latent_classifier = Dense(128, kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01), activation='relu')(self.encoder)
        self.latent_classifier = Dense(64,  kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01), activation='relu')(self.latent_classifier)
        self.latent_classifier = Dense(32,  kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01), activation='relu')(self.latent_classifier)

        self.latent_classifier = Dense(self.num_classes, activation='softmax',name='classifier_output')(self.latent_classifier)
        
    def build_vae(self, use_latent_classifier=False):
        """ Building the whole variational autoencoder Model from self.encoder and self.decoder with 
        self.input as input. It is used self.custom_loss as the model loss function.
        """
        if self.encoder is None:
            raise RuntimeError("The encoder has to be built before you can build the autoencoder!")
        if self.decoder is None:
            raise RuntimeError("The decoder has to be built before you can build the autoencoder!")
        
        if use_latent_classifier:
            if self.latent_classifier is None:
                raise RuntimeError("If you want to use the option with the latent classifier, you have to build it "
                                   "beforehand!")
            self.VAE = Model(self.input, outputs=[self.decoder, self.latent_classifier])
            self.VAE.compile(loss=self.custom_loss(self.encoded_mean, self.encoded_var), loss_weights=[1, 0.1], optimizer='adam')#, metrics="accuracy")
        else:
            self.VAE = Model(self.input, outputs=self.decoder)
            self.VAE.compile(optimizer='adam', loss=self.custom_loss(self.encoded_mean, self.encoded_var))
            self.VAE.summary()

    def sampling(self, args):
        """ Implement the Reparameterization trick. The function returns
         a vector randomly sampled from the latent space.
         # Arguments
        args (tensor): mean and log of variance of Q(z|X)
         # Returns
            z (tensor): sampled latent vector   
        """
        z_mean, z_log_var = args
        batch = K.shape(z_mean)[0]
        dim = K.int_shape(z_mean)[1]
        # we apply the multigaussian noise to every points at once
        epsilon = K.random_normal(shape=(batch, dim))
        return z_mean + K.exp(0.5 * z_log_var) * epsilon
    

    def custom_loss(self, mean, var):
        """Implement the loss function for the variational autoencoder."""
        
        def loss(y_true, y_pred):

            reconstruction_loss = tf.losses.mean_squared_error(y_true, y_pred)*784
            kl_loss = 1. + var - K.square(mean) - K.exp(var)
            kl_loss = K.sum(kl_loss, axis=-1)
            kl_loss *= -0.5
            beta = 1.0*10**-2
            return K.mean(reconstruction_loss + beta*kl_loss)

        return loss
        
        
    def fit_data(self, batch_size=128, epochs=50, use_latent_classifier=False):
        """Write the fit function for the autoencoder. 
        Store the fit history in self.history to be able to plot the fitting scores."""
        
        if use_latent_classifier:
            self.history = self.VAE.fit(self.x_train, [self.x_train, self.y_train],
                                                validation_data=(self.x_test, [self.x_test, self.y_test]),
                                                batch_size=batch_size, epochs=epochs,
                                                shuffle=True,
                                                )
        else:
            self.history = self.VAE.fit(self.x_train, self.x_train, validation_data=(self.x_test, self.x_test),
                                                batch_size=batch_size, epochs=epochs,
                                                shuffle=True,
                                                )
        
        self.history = self.history.history

    def dir(self):
        """Creation of the directories"""
        dir = os.path.join("images")
        if not os.path.exists(dir):
            os.mkdir(dir)
        dir2 = os.path.join("./images/VAE")
        if not os.path.exists(dir2):
            os.mkdir(dir2)
    
    def plot_score(self, model_name=None):
        """Plots the scores achieved during the fitting."""
        plt.plot(self.history['loss'])
        plt.plot(self.history['val_loss'])
        plt.ylabel('Model Accuracy')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Test'], loc='best')
        plt.title('Accuracy of {model_name}'.format(model_name=model_name))
        
        self.dir()
        plt.savefig('./images/VAE/Accuracy of {model_name}.png'.format(model_name=model_name))
        
        plt.show()

    def plot_latent_dimension(self, model_name=None):
        """Plots the latent dimension of the autoencoder."""
        prediction = self.encoder_model.predict(self.x_test)
        fig = plt.figure(figsize=(10, 10))
        fig.patch.set_facecolor("white")
        plt.scatter(prediction[2][:, 0], prediction[2][:, 1], c=np.argmax(self.y_test, axis=1) , cmap="Set3")
        plt.colorbar()
        
        self.dir()
        plt.savefig('./images/VAE/Latent dimension of {model_name}.png'.format(model_name=model_name))

        plt.show()

# %%
network = VAE(data)
network.build_encoder()
network.build_decoder()
network.build_vae()
network.fit_data()
network.dir()
network.plot_latent_dimension("Variational Autoencoder without classifier")
network.plot_score("Variational Autoencoder without classifier")
# Out:
# Model: "functional_16"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      [(None, 784)]        0
# __________________________________________________________________________________________________
# dense_54 (Dense)                (None, 512)          401920      encoder_input[0][0]
# __________________________________________________________________________________________________
# dense_55 (Dense)                (None, 64)           32832       dense_54[0][0]
# __________________________________________________________________________________________________
# dense_56 (Dense)                (None, 2)            130         dense_55[0][0]
# __________________________________________________________________________________________________
# dense_57 (Dense)                (None, 2)            130         dense_55[0][0]
# __________________________________________________________________________________________________
# encoder_output (Lambda)         (None, 2)            0           dense_56[0][0]
#                                                                  dense_57[0][0]
# __________________________________________________________________________________________________
# dense_58 (Dense)                (None, 64)           192         encoder_output[0][0]
# __________________________________________________________________________________________________
# dense_59 (Dense)                (None, 512)          33280       dense_58[0][0]
# __________________________________________________________________________________________________
# decoder_output (Dense)          (None, 784)          402192      dense_59[0][0]
# ==================================================================================================
# Total params: 870,676
# Trainable params: 870,676
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 5s 80us/sample - loss: 44.7935 - val_loss: 36.9875
# Epoch 2/50
# 60000/60000 [==============================] - 4s 74us/sample - loss: 35.5665 - val_loss: 34.3296
# Epoch 3/50
# 60000/60000 [==============================] - 5s 78us/sample - loss: 33.5200 - val_loss: 32.8761
# Epoch 4/50
# 60000/60000 [==============================] - 4s 74us/sample - loss: 32.4107 - val_loss: 32.1394
# Epoch 5/50
# 60000/60000 [==============================] - 4s 73us/sample - loss: 31.6957 - val_loss: 31.6415
# Epoch 6/50
# 60000/60000 [==============================] - 4s 73us/sample - loss: 31.1425 - val_loss: 31.2515
# Epoch 7/50
# 60000/60000 [==============================] - 4s 75us/sample - loss: 30.6919 - val_loss: 30.7583
# Epoch 8/50
# 60000/60000 [==============================] - 4s 72us/sample - loss: 30.3175 - val_loss: 30.5280
# Epoch 9/50
# 60000/60000 [==============================] - 5s 76us/sample - loss: 29.9648 - val_loss: 30.2813
# Epoch 10/50
# 60000/60000 [==============================] - 4s 73us/sample - loss: 29.6688 - val_loss: 30.1456
# Epoch 11/50
# 60000/60000 [==============================] - 5s 76us/sample - loss: 29.4269 - val_loss: 29.8604
# Epoch 12/50
# 60000/60000 [==============================] - 4s 73us/sample - loss: 29.1976 - val_loss: 29.9538
# Epoch 13/50
# 60000/60000 [==============================] - 4s 73us/sample - loss: 29.0023 - val_loss: 29.6009
# Epoch 14/50
# 60000/60000 [==============================] - 4s 75us/sample - loss: 28.7840 - val_loss: 29.3963
# Epoch 15/50
# 60000/60000 [==============================] - 4s 75us/sample - loss: 28.6249 - val_loss: 29.3892
# Epoch 16/50
# 60000/60000 [==============================] - 5s 76us/sample - loss: 28.4932 - val_loss: 29.1017
# Epoch 17/50
# 60000/60000 [==============================] - 4s 75us/sample - loss: 28.3020 - val_loss: 29.0541
# Epoch 18/50
# 60000/60000 [==============================] - 5s 77us/sample - loss: 28.1734 - val_loss: 29.0049
# Epoch 19/50
# 60000/60000 [==============================] - 5s 77us/sample - loss: 28.0563 - val_loss: 28.9603
# Epoch 20/50
# 60000/60000 [==============================] - 5s 76us/sample - loss: 27.9173 - val_loss: 28.8718
# Epoch 21/50
# 60000/60000 [==============================] - 4s 74us/sample - loss: 27.8515 - val_loss: 28.7282
# Epoch 22/50
# 60000/60000 [==============================] - 4s 74us/sample - loss: 27.7040 - val_loss: 28.7157
# Epoch 23/50
# 60000/60000 [==============================] - 4s 74us/sample - loss: 27.5820 - val_loss: 28.5668
# Epoch 24/50
# 60000/60000 [==============================] - 4s 74us/sample - loss: 27.4631 - val_loss: 28.4767
# Epoch 25/50
# 60000/60000 [==============================] - 4s 74us/sample - loss: 27.4042 - val_loss: 28.4493
# Epoch 26/50
# 60000/60000 [==============================] - 5s 76us/sample - loss: 27.3507 - val_loss: 28.4599
# Epoch 27/50
# 60000/60000 [==============================] - 4s 74us/sample - loss: 27.2256 - val_loss: 28.4848
# Epoch 28/50
# 60000/60000 [==============================] - 5s 76us/sample - loss: 27.1906 - val_loss: 28.4502
# Epoch 29/50
# 60000/60000 [==============================] - 4s 75us/sample - loss: 27.1420 - val_loss: 28.3257
# Epoch 30/50
# 60000/60000 [==============================] - 4s 75us/sample - loss: 27.0698 - val_loss: 28.3532
# Epoch 31/50
# 60000/60000 [==============================] - 4s 75us/sample - loss: 26.9955 - val_loss: 28.3291
# Epoch 32/50
# 60000/60000 [==============================] - 5s 78us/sample - loss: 26.9248 - val_loss: 28.2389
# Epoch 33/50
# 60000/60000 [==============================] - 4s 75us/sample - loss: 26.8641 - val_loss: 28.2181
# Epoch 34/50
# 60000/60000 [==============================] - 5s 78us/sample - loss: 26.8439 - val_loss: 28.0724
# Epoch 35/50
# 60000/60000 [==============================] - 5s 77us/sample - loss: 26.7703 - val_loss: 28.1714
# Epoch 36/50
# 60000/60000 [==============================] - 5s 79us/sample - loss: 26.6680 - val_loss: 28.1814
# Epoch 37/50
# 60000/60000 [==============================] - 5s 80us/sample - loss: 26.6481 - val_loss: 28.1454
# Epoch 38/50
# 60000/60000 [==============================] - 5s 78us/sample - loss: 26.6586 - val_loss: 28.1634
# Epoch 39/50
# 60000/60000 [==============================] - 5s 79us/sample - loss: 26.5832 - val_loss: 28.1186
# Epoch 40/50
# 60000/60000 [==============================] - 5s 77us/sample - loss: 26.5394 - val_loss: 28.1374
# Epoch 41/50
# 60000/60000 [==============================] - 5s 78us/sample - loss: 26.4841 - val_loss: 28.0643
# Epoch 42/50
# 60000/60000 [==============================] - 5s 78us/sample - loss: 26.4903 - val_loss: 28.2369
# Epoch 43/50
# 60000/60000 [==============================] - 5s 78us/sample - loss: 26.3708 - val_loss: 28.0268
# Epoch 44/50
# 60000/60000 [==============================] - 5s 78us/sample - loss: 26.3678 - val_loss: 28.1061
# Epoch 45/50
# 60000/60000 [==============================] - 4s 74us/sample - loss: 26.3504 - val_loss: 28.0562
# Epoch 46/50
# 60000/60000 [==============================] - 5s 76us/sample - loss: 26.2779 - val_loss: 27.9571
# Epoch 47/50
# 60000/60000 [==============================] - 5s 75us/sample - loss: 26.2457 - val_loss: 28.0293
# Epoch 48/50
# 60000/60000 [==============================] - 4s 72us/sample - loss: 26.2517 - val_loss: 28.0202
# Epoch 49/50
# 60000/60000 [==============================] - 4s 72us/sample - loss: 26.1713 - val_loss: 27.9624
# Epoch 50/50
# 60000/60000 [==============================] - 5s 78us/sample - loss: 26.1412 - val_loss: 28.0376

# %%
network_with_classifier = VAE(data)
network_with_classifier.build_encoder()
network_with_classifier.build_decoder()
network_with_classifier.build_classifier()
network_with_classifier.build_vae(use_latent_classifier=True)
network_with_classifier.fit_data(use_latent_classifier=True)
network_with_classifier.dir()
network_with_classifier.plot_latent_dimension("Variational Autoencoder with classifier")
network_with_classifier.plot_score("Variational Autoencoder with classifier")
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 5s 84us/sample - loss: 50.4997 - decoder_output_loss: 45.3352 - classifier_output_loss: 46.2553 - val_loss: 40.5507 - val_decoder_output_loss: 37.8398 - val_classifier_output_loss: 22.1625
# Epoch 2/50
# 60000/60000 [==============================] - 5s 85us/sample - loss: 38.8582 - decoder_output_loss: 36.5926 - classifier_output_loss: 17.7642 - val_loss: 37.5542 - val_decoder_output_loss: 35.3251 - val_classifier_output_loss: 17.5131
# Epoch 3/50
# 60000/60000 [==============================] - 5s 82us/sample - loss: 36.1823 - decoder_output_loss: 34.4484 - classifier_output_loss: 12.8442 - val_loss: 35.4219 - val_decoder_output_loss: 33.7728 - val_classifier_output_loss: 12.6102
# Epoch 4/50
# 60000/60000 [==============================] - 5s 79us/sample - loss: 34.5145 - decoder_output_loss: 33.0154 - classifier_output_loss: 10.8302 - val_loss: 33.9082 - val_decoder_output_loss: 32.4326 - val_classifier_output_loss: 11.1075
# Epoch 5/50
# 60000/60000 [==============================] - 5s 82us/sample - loss: 33.4193 - decoder_output_loss: 32.0559 - classifier_output_loss: 9.7317 - val_loss: 33.2972 - val_decoder_output_loss: 31.8400 - val_classifier_output_loss: 10.2100
# Epoch 6/50
# 60000/60000 [==============================] - 5s 77us/sample - loss: 32.6015 - decoder_output_loss: 31.3278 - classifier_output_loss: 9.0143 - val_loss: 32.7097 - val_decoder_output_loss: 31.2890 - val_classifier_output_loss: 10.3814
# Epoch 7/50
# 60000/60000 [==============================] - 5s 78us/sample - loss: 31.9663 - decoder_output_loss: 30.7620 - classifier_output_loss: 8.4765 - val_loss: 32.1265 - val_decoder_output_loss: 30.8532 - val_classifier_output_loss: 9.9236
# Epoch 8/50
# 60000/60000 [==============================] - 5s 83us/sample - loss: 31.4310 - decoder_output_loss: 30.2959 - classifier_output_loss: 7.9176 - val_loss: 31.5822 - val_decoder_output_loss: 30.3854 - val_classifier_output_loss: 9.5536
# Epoch 9/50
# 60000/60000 [==============================] - 5s 80us/sample - loss: 30.9917 - decoder_output_loss: 29.9010 - classifier_output_loss: 7.6014 - val_loss: 31.3139 - val_decoder_output_loss: 29.9725 - val_classifier_output_loss: 9.6798
# Epoch 10/50
# 60000/60000 [==============================] - 5s 85us/sample - loss: 30.5998 - decoder_output_loss: 29.5546 - classifier_output_loss: 7.2512 - val_loss: 30.9358 - val_decoder_output_loss: 29.7527 - val_classifier_output_loss: 8.6758
# Epoch 11/50
# 60000/60000 [==============================] - 5s 78us/sample - loss: 30.2838 - decoder_output_loss: 29.2702 - classifier_output_loss: 7.0290 - val_loss: 30.5938 - val_decoder_output_loss: 29.4520 - val_classifier_output_loss: 8.7750
# Epoch 12/50
# 60000/60000 [==============================] - 5s 85us/sample - loss: 29.9839 - decoder_output_loss: 28.9984 - classifier_output_loss: 6.8375 - val_loss: 30.5312 - val_decoder_output_loss: 29.3814 - val_classifier_output_loss: 8.8260
# Epoch 13/50
# 60000/60000 [==============================] - 5s 88us/sample - loss: 29.6833 - decoder_output_loss: 28.7310 - classifier_output_loss: 6.6035 - val_loss: 30.3340 - val_decoder_output_loss: 29.2157 - val_classifier_output_loss: 8.5888
# Epoch 14/50
# 60000/60000 [==============================] - 5s 82us/sample - loss: 29.4647 - decoder_output_loss: 28.5288 - classifier_output_loss: 6.4957 - val_loss: 30.0613 - val_decoder_output_loss: 28.9530 - val_classifier_output_loss: 8.3732
# Epoch 15/50
# 60000/60000 [==============================] - 5s 87us/sample - loss: 29.2443 - decoder_output_loss: 28.3340 - classifier_output_loss: 6.3273 - val_loss: 29.9440 - val_decoder_output_loss: 28.8047 - val_classifier_output_loss: 8.5752
# Epoch 16/50
# 60000/60000 [==============================] - 5s 80us/sample - loss: 29.0215 - decoder_output_loss: 28.1393 - classifier_output_loss: 6.1308 - val_loss: 29.7943 - val_decoder_output_loss: 28.7092 - val_classifier_output_loss: 8.4534
# Epoch 17/50
# 60000/60000 [==============================] - 5s 81us/sample - loss: 28.8580 - decoder_output_loss: 27.9804 - classifier_output_loss: 6.1457 - val_loss: 29.7590 - val_decoder_output_loss: 28.6592 - val_classifier_output_loss: 8.4557
# Epoch 18/50
# 60000/60000 [==============================] - 5s 85us/sample - loss: 28.6545 - decoder_output_loss: 27.7992 - classifier_output_loss: 5.9833 - val_loss: 29.5707 - val_decoder_output_loss: 28.4447 - val_classifier_output_loss: 8.4877
# Epoch 19/50
# 60000/60000 [==============================] - 5s 80us/sample - loss: 28.5144 - decoder_output_loss: 27.6722 - classifier_output_loss: 5.9224 - val_loss: 29.4439 - val_decoder_output_loss: 28.3912 - val_classifier_output_loss: 8.5183
# Epoch 20/50
# 60000/60000 [==============================] - 5s 77us/sample - loss: 28.3685 - decoder_output_loss: 27.5362 - classifier_output_loss: 5.8967 - val_loss: 29.3697 - val_decoder_output_loss: 28.2949 - val_classifier_output_loss: 8.3014
# Epoch 21/50
# 60000/60000 [==============================] - 5s 81us/sample - loss: 28.2581 - decoder_output_loss: 27.4305 - classifier_output_loss: 5.8871 - val_loss: 29.2217 - val_decoder_output_loss: 28.1444 - val_classifier_output_loss: 8.1020
# Epoch 22/50
# 60000/60000 [==============================] - 5s 78us/sample - loss: 28.0799 - decoder_output_loss: 27.2780 - classifier_output_loss: 5.6803 - val_loss: 29.0351 - val_decoder_output_loss: 27.9553 - val_classifier_output_loss: 8.0971
# Epoch 23/50
# 60000/60000 [==============================] - 4s 75us/sample - loss: 27.9571 - decoder_output_loss: 27.1627 - classifier_output_loss: 5.6536 - val_loss: 29.1794 - val_decoder_output_loss: 28.1121 - val_classifier_output_loss: 8.7610
# Epoch 24/50
# 60000/60000 [==============================] - 5s 75us/sample - loss: 27.8306 - decoder_output_loss: 27.0468 - classifier_output_loss: 5.5722 - val_loss: 29.0739 - val_decoder_output_loss: 28.0236 - val_classifier_output_loss: 8.4303
# Epoch 25/50
# 60000/60000 [==============================] - 5s 87us/sample - loss: 27.7408 - decoder_output_loss: 26.9694 - classifier_output_loss: 5.5100 - val_loss: 28.9582 - val_decoder_output_loss: 27.8804 - val_classifier_output_loss: 8.0165
# Epoch 26/50
# 60000/60000 [==============================] - 5s 80us/sample - loss: 27.6314 - decoder_output_loss: 26.8666 - classifier_output_loss: 5.4797 - val_loss: 28.9864 - val_decoder_output_loss: 27.9321 - val_classifier_output_loss: 8.0294
# Epoch 27/50
# 60000/60000 [==============================] - 5s 83us/sample - loss: 27.5062 - decoder_output_loss: 26.7559 - classifier_output_loss: 5.3796 - val_loss: 28.9231 - val_decoder_output_loss: 27.9194 - val_classifier_output_loss: 8.1059
# Epoch 28/50
# 60000/60000 [==============================] - 5s 77us/sample - loss: 27.4230 - decoder_output_loss: 26.6706 - classifier_output_loss: 5.4331 - val_loss: 28.8299 - val_decoder_output_loss: 27.7831 - val_classifier_output_loss: 8.2650
# Epoch 29/50
# 60000/60000 [==============================] - 5s 77us/sample - loss: 27.3498 - decoder_output_loss: 26.6100 - classifier_output_loss: 5.3428 - val_loss: 28.8203 - val_decoder_output_loss: 27.8398 - val_classifier_output_loss: 8.1250
# Epoch 30/50
# 60000/60000 [==============================] - 5s 78us/sample - loss: 27.2857 - decoder_output_loss: 26.5480 - classifier_output_loss: 5.3574 - val_loss: 28.7826 - val_decoder_output_loss: 27.7305 - val_classifier_output_loss: 7.8736
# Epoch 31/50
# 60000/60000 [==============================] - 4s 74us/sample - loss: 27.2146 - decoder_output_loss: 26.4864 - classifier_output_loss: 5.2936 - val_loss: 28.6139 - val_decoder_output_loss: 27.6587 - val_classifier_output_loss: 8.1544
# Epoch 32/50
# 60000/60000 [==============================] - 4s 75us/sample - loss: 27.1995 - decoder_output_loss: 26.4669 - classifier_output_loss: 5.3667 - val_loss: 28.8101 - val_decoder_output_loss: 27.7812 - val_classifier_output_loss: 8.0840
# Epoch 33/50
# 60000/60000 [==============================] - 5s 80us/sample - loss: 27.1514 - decoder_output_loss: 26.4210 - classifier_output_loss: 5.3865 - val_loss: 28.5564 - val_decoder_output_loss: 27.5782 - val_classifier_output_loss: 7.9569
# Epoch 34/50
# 60000/60000 [==============================] - 5s 76us/sample - loss: 27.0720 - decoder_output_loss: 26.3562 - classifier_output_loss: 5.2809 - val_loss: 28.4847 - val_decoder_output_loss: 27.4869 - val_classifier_output_loss: 7.9961
# Epoch 35/50
# 60000/60000 [==============================] - 5s 78us/sample - loss: 26.9952 - decoder_output_loss: 26.2862 - classifier_output_loss: 5.2403 - val_loss: 28.4971 - val_decoder_output_loss: 27.4805 - val_classifier_output_loss: 7.4793
# Epoch 36/50
# 60000/60000 [==============================] - 5s 82us/sample - loss: 26.8968 - decoder_output_loss: 26.1955 - classifier_output_loss: 5.1939 - val_loss: 28.4687 - val_decoder_output_loss: 27.5211 - val_classifier_output_loss: 7.6644
# Epoch 37/50
# 60000/60000 [==============================] - 5s 80us/sample - loss: 26.8336 - decoder_output_loss: 26.1421 - classifier_output_loss: 5.1181 - val_loss: 28.4297 - val_decoder_output_loss: 27.4119 - val_classifier_output_loss: 7.6710
# Epoch 38/50
# 60000/60000 [==============================] - 5s 77us/sample - loss: 26.7916 - decoder_output_loss: 26.0970 - classifier_output_loss: 5.1676 - val_loss: 28.5356 - val_decoder_output_loss: 27.5769 - val_classifier_output_loss: 7.5071
# Epoch 39/50
# 60000/60000 [==============================] - 5s 76us/sample - loss: 26.7397 - decoder_output_loss: 26.0503 - classifier_output_loss: 5.1569 - val_loss: 28.5665 - val_decoder_output_loss: 27.6364 - val_classifier_output_loss: 8.3303
# Epoch 40/50
# 60000/60000 [==============================] - 5s 76us/sample - loss: 26.7151 - decoder_output_loss: 26.0282 - classifier_output_loss: 5.1327 - val_loss: 28.4332 - val_decoder_output_loss: 27.4983 - val_classifier_output_loss: 7.7179
# Epoch 41/50
# 60000/60000 [==============================] - 5s 79us/sample - loss: 26.6759 - decoder_output_loss: 25.9889 - classifier_output_loss: 5.1630 - val_loss: 28.4042 - val_decoder_output_loss: 27.4815 - val_classifier_output_loss: 7.6711
# Epoch 42/50
# 60000/60000 [==============================] - 5s 76us/sample - loss: 26.6257 - decoder_output_loss: 25.9493 - classifier_output_loss: 5.0744 - val_loss: 28.3619 - val_decoder_output_loss: 27.3385 - val_classifier_output_loss: 7.4986
# Epoch 43/50
# 60000/60000 [==============================] - 5s 79us/sample - loss: 26.5875 - decoder_output_loss: 25.9118 - classifier_output_loss: 5.0879 - val_loss: 28.3028 - val_decoder_output_loss: 27.3268 - val_classifier_output_loss: 8.1717
# Epoch 44/50
# 60000/60000 [==============================] - 5s 83us/sample - loss: 26.5559 - decoder_output_loss: 25.8787 - classifier_output_loss: 5.1254 - val_loss: 28.2930 - val_decoder_output_loss: 27.4807 - val_classifier_output_loss: 7.2141
# Epoch 45/50
# 60000/60000 [==============================] - 5s 83us/sample - loss: 26.4815 - decoder_output_loss: 25.8130 - classifier_output_loss: 5.0373 - val_loss: 28.3304 - val_decoder_output_loss: 27.4227 - val_classifier_output_loss: 7.5390
# Epoch 46/50
# 60000/60000 [==============================] - 5s 80us/sample - loss: 26.4593 - decoder_output_loss: 25.7909 - classifier_output_loss: 5.0813 - val_loss: 28.3048 - val_decoder_output_loss: 27.2750 - val_classifier_output_loss: 7.8380
# Epoch 47/50
# 60000/60000 [==============================] - 5s 76us/sample - loss: 26.4287 - decoder_output_loss: 25.7596 - classifier_output_loss: 5.0705 - val_loss: 28.2390 - val_decoder_output_loss: 27.2736 - val_classifier_output_loss: 7.6480
# Epoch 48/50
# 60000/60000 [==============================] - 5s 79us/sample - loss: 26.3566 - decoder_output_loss: 25.6965 - classifier_output_loss: 5.0136 - val_loss: 28.2100 - val_decoder_output_loss: 27.2388 - val_classifier_output_loss: 7.6669
# Epoch 49/50
# 60000/60000 [==============================] - 5s 76us/sample - loss: 26.3356 - decoder_output_loss: 25.6747 - classifier_output_loss: 5.0315 - val_loss: 28.1519 - val_decoder_output_loss: 27.2288 - val_classifier_output_loss: 7.5892
# Epoch 50/50
# 60000/60000 [==============================] - 5s 77us/sample - loss: 26.3334 - decoder_output_loss: 25.6748 - classifier_output_loss: 5.0164 - val_loss: 28.1478 - val_decoder_output_loss: 27.2196 - val_classifier_output_loss: 7.6113
