# %%
import tensorflow as tf
from tensorflow.python.keras.engine.functional import Functional
from tensorflow.python.keras.engine.keras_tensor import KerasTensor
from tensorflow.python.keras.models import Model

import numpy as np
from matplotlib import pyplot as plt
from tensorflow.keras.layers import Dense, Reshape
from tensorflow.python.keras.utils.np_utils import to_categorical
from tensorflow.python.keras.regularizers import l2

import os

# %% [markdown]
# ### Import the MNIST data class and call it.

# %%
import MNIST_dataset as mnist
data = mnist.MNISTData()

# %% [markdown]
# # Autoencoder using Keras
# The aim of this class is to implement a simple autoencoder for the MNIST data and then build an autoencoder that is
# able to classify MNIST data in its latent dimension.
#
# Code partially adapted from [Keras Documentation](https://blog.keras.io/building-autoencoders-in-keras.html).

# %%
class Autoencoder:
    """Autoencoder Class"""
    def __init__(self, data: mnist.MNISTData, num_classes=10):
        self.x_train = data.x_train
        self.x_test = data.x_test
        self.y_train = data.y_train
        self.y_test = data.y_test

        self.num_classes = num_classes
        self.input_shape = self.x_train[0].shape
        self.input = Input(shape=self.input_shape,name='encoder_input' )

        self.encoder = None
        self.encoder_model = None
        self.decoder = None
        self.latent_classifier = None
        self.autoencoder = None

        self.history = None

    def build_encoder(self):
        """Build your encoder architecture and store the output in self.encoder. 
        The final encoding dimension is 2."""
        self.encoder = Dense(128,  activation='relu')(self.input)
        self.encoder = Dense(64,  activation='relu')(self.encoder)
        self.encoder = Dense(2,  activation='relu', name = 'encoder_output')(self.encoder)      
        
        #building a model for the encoder in order to be able to predict and plot the latent dimension
        self.encoder_model = Model(self.input, self.encoder, name='encoder')

    def build_decoder(self):
        """Build the decoder architecture."""
        if self.encoder is None:
            raise RuntimeError("The encoder has to be built before you can build the decoder!")
        self.decoder = Dense(64, activation='relu')(self.encoder)
        self.decoder = Dense(128, activation='relu')(self.decoder)
        self.decoder = Dense(784,activation='sigmoid', name='ecoder_output')(self.decoder)

    def build_classifier(self):
        """ Building the classifier architecture."""
        if self.encoder is None:
            raise RuntimeError("The encoder has to be built before you can build the classifier!")
        self.latent_classifier = Dense(128, kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01), activation='relu')(self.encoder)
        self.latent_classifier = Dense(64, kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01), activation='relu')(self.latent_classifier)
        self.latent_classifier = Dense(32, kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01), activation='relu')(self.latent_classifier)

        self.latent_classifier = Dense(self.num_classes, activation='softmax',name='classifier_output')(self.latent_classifier)

    def build_autoencoder(self, use_latent_classifier=False):
        """ Build the whole autoencoder Model from self.encoder and self.decoder."""
        if self.encoder is None:
            raise RuntimeError("The encoder has to be built before you can build the autoencoder!")
        if self.decoder is None:
            raise RuntimeError("The decoder has to be built before you can build the autoencoder!")

        if use_latent_classifier:
            if self.latent_classifier is None:
                raise RuntimeError("If you want to use the option with the latent classifier, you have to build it "
                                   "beforehand!")
            self.autoencoder = Model(self.input, outputs=[self.decoder, self.latent_classifier])
            self.autoencoder.compile(loss=['mse', 'categorical_crossentropy'], loss_weights=[1, 0.1], optimizer='adam',
                                     metrics="accuracy")
        else:
            self.autoencoder = Model(self.input, outputs=self.decoder)
            self.autoencoder.compile(loss='mse', optimizer='adam')

    def fit_data(self, batch_size=128, epochs=50, use_latent_classifier=False):
        """Write the fit function for the autoencoder. 
        Storing the fit history in self.history to be able to plot the fitting scores."""
        if use_latent_classifier:
            self.history = self.autoencoder.fit(self.x_train, [self.x_train, self.y_train],
                                                validation_data=(self.x_test, [self.x_test, self.y_test]),
                                                batch_size=batch_size, epochs=epochs,
                                                shuffle=True,
                                                )
        else:
            self.history = self.autoencoder.fit(self.x_train, self.x_train,
                                                validation_data=(self.x_test, self.x_test),
                                                batch_size=batch_size, epochs=epochs,
                                                shuffle=True,
                                                )

        self.history = self.history.history

    def dir(self):
        """Creation of the folders path to store the results."""
        dir = os.path.join("images")
        if not os.path.exists(dir):
            os.mkdir(dir)
        dir2 = os.path.join("./images/AE")
        if not os.path.exists(dir2):
            os.mkdir(dir2)
    
    def plot_score(self, model_name=None):
        """Plots the scores achieved during the fitting."""
        plt.plot(self.history['loss'])
        plt.plot(self.history['val_loss'])
        plt.ylabel('Model Accuracy')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Test'], loc='best')
        plt.title('Accuracy of {model_name}'.format(model_name=model_name))
        
        plt.savefig('./images/AE/Accuracy of {model_name}.png'.format(model_name=model_name))
        
        plt.show()

    def plot_latent_dimension(self, model_name = None):
        """Plots the latent dimension of the autoencoder."""
        prediction = self.encoder_model.predict(self.x_test)
        fig = plt.figure(figsize=(10, 10))
        fig.patch.set_facecolor("white")
        plt.scatter(prediction[:, 0], prediction[:, 1], c=np.argmax(self.y_test, axis=1), cmap="Set3")
        plt.colorbar()

        plt.savefig('./images/AE/Latent dimension of {model_name}.png'.format(model_name=model_name))

        plt.show()

    def plot_reco(self, use_latent_classifier = False):
        """Plotting reconstructed images"""
        
        n = 6
        plt.figure(figsize=(10, 3))
        reco_imgs = self.autoencoder.predict(self.x_test)
        
        if use_latent_classifier :
            raise RuntimeError("You are considering the autoencoder with classifier!")
        else:
        
            for i in range(n):
                # Display original MNIST
                ax = plt.subplot(2, n, i + 1)
                plt.imshow(self.x_test[i].reshape(28,28), cmap='gray_r')
                ax.get_xaxis().set_visible(False)
                ax.get_yaxis().set_visible(False)

                # Display reconstructed MNIST            
                ax = plt.subplot(2, n, i + n + 1)
                plt.imshow(reco_imgs[i].reshape(28,28), cmap='gray_r')
                ax.get_xaxis().set_visible(False)
                ax.get_yaxis().set_visible(False)
            plt.savefig('./images/AE/reconstructed images.png')
            plt.show()

# %% [markdown]
# It is built the standard autoencoder, *without classifier* here, and the MNIST data class called before is used.
# The model is fitted and adequate plots are reproduced,
# as well as the comparison between orginal MNIST dataset and reconstructed images.

# %%
network = Autoencoder(data)
network.build_encoder()
network.build_decoder()
network.build_autoencoder()
network.dir()
network.fit_data()
network.plot_latent_dimension("Autoencoder without classifier")
network.plot_reco()
network.plot_score("Autoencoder without classifier")
# Out:
# Epoch 1/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0676 - val_loss: 0.0542
# Epoch 2/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0522 - val_loss: 0.0504
# Epoch 3/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0489 - val_loss: 0.0475
# Epoch 4/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0465 - val_loss: 0.0457
# Epoch 5/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0450 - val_loss: 0.0445
# Epoch 6/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0439 - val_loss: 0.0436
# Epoch 7/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0431 - val_loss: 0.0429
# Epoch 8/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0424 - val_loss: 0.0423
# Epoch 9/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0418 - val_loss: 0.0417
# Epoch 10/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0413 - val_loss: 0.0413
# Epoch 11/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0409 - val_loss: 0.0409
# Epoch 12/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0406 - val_loss: 0.0408
# Epoch 13/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0403 - val_loss: 0.0405
# Epoch 14/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0400 - val_loss: 0.0402
# Epoch 15/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0398 - val_loss: 0.0400
# Epoch 16/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0396 - val_loss: 0.0399
# Epoch 17/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0394 - val_loss: 0.0398
# Epoch 18/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0393 - val_loss: 0.0395
# Epoch 19/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0391 - val_loss: 0.0396
# Epoch 20/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0389 - val_loss: 0.0393
# Epoch 21/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0388 - val_loss: 0.0393
# Epoch 22/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0386 - val_loss: 0.0391
# Epoch 23/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0385 - val_loss: 0.0389
# Epoch 24/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0384 - val_loss: 0.0392
# Epoch 25/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0382 - val_loss: 0.0388
# Epoch 26/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0382 - val_loss: 0.0388
# Epoch 27/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0381 - val_loss: 0.0386
# Epoch 28/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0379 - val_loss: 0.0385
# Epoch 29/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0378 - val_loss: 0.0384
# Epoch 30/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0378 - val_loss: 0.0384
# Epoch 31/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0376 - val_loss: 0.0383
# Epoch 32/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0375 - val_loss: 0.0384
# Epoch 33/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0375 - val_loss: 0.0383
# Epoch 34/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0374 - val_loss: 0.0381
# Epoch 35/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0373 - val_loss: 0.0382
# Epoch 36/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0373 - val_loss: 0.0381
# Epoch 37/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0372 - val_loss: 0.0382
# Epoch 38/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0372 - val_loss: 0.0380
# Epoch 39/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0371 - val_loss: 0.0378
# Epoch 40/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0370 - val_loss: 0.0378
# Epoch 41/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0369 - val_loss: 0.0380
# Epoch 42/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0370 - val_loss: 0.0378
# Epoch 43/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0369 - val_loss: 0.0378
# Epoch 44/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0368 - val_loss: 0.0378
# Epoch 45/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0368 - val_loss: 0.0378
# Epoch 46/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0367 - val_loss: 0.0378
# Epoch 47/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0367 - val_loss: 0.0376
# Epoch 48/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0366 - val_loss: 0.0376
# Epoch 49/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0366 - val_loss: 0.0378
# Epoch 50/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0366 - val_loss: 0.0376

# %% [markdown]
# Repeating the same procedure for the autoencoder with classifier.

# %%
network_with_classifier = Autoencoder(data)
network_with_classifier.build_encoder()
network_with_classifier.build_decoder()
network_with_classifier.build_classifier()
network_with_classifier.build_autoencoder(use_latent_classifier=True)
network_with_classifier.fit_data( use_latent_classifier=True)
network_with_classifier.dir()
network_with_classifier.plot_latent_dimension("Autoencoder with classifier")
network_with_classifier.plot_score("Autoencoder with classifier")
# Out:
# Epoch 1/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.4106 - ecoder_output_loss: 0.0709 - classifier_output_loss: 1.4157 - ecoder_output_accuracy: 0.0065 - classifier_output_accuracy: 0.4576 - val_loss: 0.1990 - val_ecoder_output_loss: 0.0608 - val_classifier_output_loss: 1.1222 - val_ecoder_output_accuracy: 0.0085 - val_classifier_output_accuracy: 0.6173
# Epoch 2/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.1763 - ecoder_output_loss: 0.0577 - classifier_output_loss: 0.9631 - ecoder_output_accuracy: 0.0085 - classifier_output_accuracy: 0.7045 - val_loss: 0.1656 - val_ecoder_output_loss: 0.0541 - val_classifier_output_loss: 0.9135 - val_ecoder_output_accuracy: 0.0082 - val_classifier_output_accuracy: 0.7388
# Epoch 3/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.1501 - ecoder_output_loss: 0.0535 - classifier_output_loss: 0.7733 - ecoder_output_accuracy: 0.0063 - classifier_output_accuracy: 0.7878 - val_loss: 0.1429 - val_ecoder_output_loss: 0.0528 - val_classifier_output_loss: 0.7176 - val_ecoder_output_accuracy: 0.0066 - val_classifier_output_accuracy: 0.8124
# Epoch 4/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.1353 - ecoder_output_loss: 0.0524 - classifier_output_loss: 0.6481 - ecoder_output_accuracy: 0.0065 - classifier_output_accuracy: 0.8292 - val_loss: 0.1306 - val_ecoder_output_loss: 0.0516 - val_classifier_output_loss: 0.6152 - val_ecoder_output_accuracy: 0.0067 - val_classifier_output_accuracy: 0.8443
# Epoch 5/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.1244 - ecoder_output_loss: 0.0519 - classifier_output_loss: 0.5567 - ecoder_output_accuracy: 0.0069 - classifier_output_accuracy: 0.8559 - val_loss: 0.1211 - val_ecoder_output_loss: 0.0515 - val_classifier_output_loss: 0.5317 - val_ecoder_output_accuracy: 0.0094 - val_classifier_output_accuracy: 0.8658
# Epoch 6/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.
50
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0659 - ecoder_output_loss: 0.0450 - classifier_output_loss: 0.1375 - ecoder_output_accuracy: 0.0163 - classifier_output_accuracy: 0.9687 - val_loss: 0.0784 - val_ecoder_output_loss: 0.0450 - val_classifier_output_loss: 0.2635 - val_ecoder_output_accuracy: 0.0123 - val_classifier_output_accuracy: 0.9378
# Epoch 34/50
# 469/469 [==============================] - 5s 12ms/step - loss: 0.0652 - ecoder_output_loss: 0.0448 - classifier_output_loss: 0.1332 - ecoder_output_accuracy: 0.0165 - classifier_output_accuracy: 0.9694 - val_loss: 0.0796 - val_ecoder_output_loss: 0.0451 - val_classifier_output_loss: 0.2743 - val_ecoder_output_accuracy: 0.0133 - val_classifier_output_accuracy: 0.9356
# Epoch 35/50
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0649 - ecoder_output_loss: 0.0448 - classifier_output_loss: 0.1316 - ecoder_output_accuracy: 0.0148 - classifier_output_accuracy: 0.9696 - val_loss: 0.0801 - val_ecoder_output_loss: 0.0454 - val_classifier_output_loss: 0.2790 - val_ecoder_output_accuracy: 0.0131 - val_classifier_output_accuracy: 0.9348
# Epoch 36/50
# 469/469 [==============================] - 5s 12ms/step - loss: 0.0644 - ecoder_output_loss: 0.0447 - classifier_output_loss: 0.1277 - ecoder_output_accuracy: 0.0172 - classifier_output_accuracy: 0.9710 - val_loss: 0.0792 - val_ecoder_output_loss: 0.0453 - val_classifier_output_loss: 0.2707 - val_ecoder_output_accuracy: 0.0170 - val_classifier_output_accuracy: 0.9356
# Epoch 37/50
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0638 - ecoder_output_loss: 0.0446 - classifier_output_loss: 0.1251 - ecoder_output_accuracy: 0.0168 - classifier_output_accuracy: 0.9717 - val_loss: 0.0794 - val_ecoder_output_loss: 0.0453 - val_classifier_output_loss: 0.2737 - val_ecoder_output_accuracy: 0.0140 - val_classifier_output_accuracy: 0.9354
# Epoch 38/50
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0633 - ecoder_output_loss: 0.0445 - classifier_output_loss: 0.1211 - ecoder_output_accuracy: 0.0155 - classifier_output_accuracy: 0.9729 - val_loss: 0.0778 - val_ecoder_output_loss: 0.0447 - val_classifier_output_loss: 0.2667 - val_ecoder_output_accuracy: 0.0136 - val_classifier_output_accuracy: 0.9398
# Epoch 39/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0633 - ecoder_output_loss: 0.0445 - classifier_output_loss: 0.1219 - ecoder_output_accuracy: 0.0166 - classifier_output_accuracy: 0.9725 - val_loss: 0.0794 - val_ecoder_output_loss: 0.0450 - val_classifier_output_loss: 0.2776 - val_ecoder_output_accuracy: 0.0157 - val_classifier_output_accuracy: 0.9366
# Epoch 40/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0626 - ecoder_output_loss: 0.0443 - classifier_output_loss: 0.1177 - ecoder_output_accuracy: 0.0166 - classifier_output_accuracy: 0.9730 - val_loss: 0.0780 - val_ecoder_output_loss: 0.0446 - val_classifier_output_loss: 0.2699 - val_ecoder_output_accuracy: 0.0138 - val_classifier_output_accuracy: 0.9381
# Epoch 41/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0623 - ecoder_output_loss: 0.0443 - classifier_output_loss: 0.1156 - ecoder_output_accuracy: 0.0166 - classifier_output_accuracy: 0.9727 - val_loss: 0.0792 - val_ecoder_output_loss: 0.0445 - val_classifier_output_loss: 0.2833 - val_ecoder_output_accuracy: 0.0161 - val_classifier_output_accuracy: 0.9378
# Epoch 42/50
# 469/469 [==============================] - 5s 12ms/step - loss: 0.0617 - ecoder_output_loss: 0.0442 - classifier_output_loss: 0.1124 - ecoder_output_accuracy: 0.0157 - classifier_output_accuracy: 0.9748 - val_loss: 0.0778 - val_ecoder_output_loss: 0.0445 - val_classifier_output_loss: 0.2704 - val_ecoder_output_accuracy: 0.0150 - val_classifier_output_accuracy: 0.9371
# Epoch 43/50
# 469/469 [==============================] - 5s 12ms/step - loss: 0.0613 - ecoder_output_loss: 0.0441 - classifier_output_loss: 0.1107 - ecoder_output_accuracy: 0.0162 - classifier_output_accuracy: 0.9748 - val_loss: 0.0782 - val_ecoder_output_loss: 0.0444 - val_classifier_output_loss: 0.2785 - val_ecoder_output_accuracy: 0.0149 - val_classifier_output_accuracy: 0.9395
# Epoch 44/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0612 - ecoder_output_loss: 0.0440 - classifier_output_loss: 0.1102 - ecoder_output_accuracy: 0.0165 - classifier_output_accuracy: 0.9750 - val_loss: 0.0785 - val_ecoder_output_loss: 0.0444 - val_classifier_output_loss: 0.2791 - val_ecoder_output_accuracy: 0.0152 - val_classifier_output_accuracy: 0.9376
# Epoch 45/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0608 - ecoder_output_loss: 0.0439 - classifier_output_loss: 0.1085 - ecoder_output_accuracy: 0.0159 - classifier_output_accuracy: 0.9755 - val_loss: 0.0778 - val_ecoder_output_loss: 0.0442 - val_classifier_output_loss: 0.2757 - val_ecoder_output_accuracy: 0.0166 - val_classifier_output_accuracy: 0.9376
# Epoch 46/50
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0603 - ecoder_output_loss: 0.0439 - classifier_output_loss: 0.1049 - ecoder_output_accuracy: 0.0170 - classifier_output_accuracy: 0.9761 - val_loss: 0.0792 - val_ecoder_output_loss: 0.0445 - val_classifier_output_loss: 0.2890 - val_ecoder_output_accuracy: 0.0154 - val_classifier_output_accuracy: 0.9373
# Epoch 47/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0599 - ecoder_output_loss: 0.0437 - classifier_output_loss: 0.1031 - ecoder_output_accuracy: 0.0169 - classifier_output_accuracy: 0.9769 - val_loss: 0.0767 - val_ecoder_output_loss: 0.0438 - val_classifier_output_loss: 0.2701 - val_ecoder_output_accuracy: 0.0138 - val_classifier_output_accuracy: 0.9394
# Epoch 48/50
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0595 - ecoder_output_loss: 0.0436 - classifier_output_loss: 0.1003 - ecoder_output_accuracy: 0.0162 - classifier_output_accuracy: 0.9775 - val_loss: 0.0771 - val_ecoder_output_loss: 0.0438 - val_classifier_output_loss: 0.2763 - val_ecoder_output_accuracy: 0.0154 - val_classifier_output_accuracy: 0.9387
# Epoch 49/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0594 - ecoder_output_loss: 0.0436 - classifier_output_loss: 0.1005 - ecoder_output_accuracy: 0.0169 - classifier_output_accuracy: 0.9772 - val_loss: 0.0778 - val_ecoder_output_loss: 0.0439 - val_classifier_output_loss: 0.2806 - val_ecoder_output_accuracy: 0.0167 - val_classifier_output_accuracy: 0.9392
# Epoch 50/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0592 - ecoder_output_loss: 0.0436 - classifier_output_loss: 0.0995 - ecoder_output_accuracy: 0.0168 - classifier_output_accuracy: 0.9772 - val_loss: 0.0792 - val_ecoder_output_loss: 0.0441 - val_classifier_output_loss: 0.2933 - val_ecoder_output_accuracy: 0.0151 - val_classifier_output_accuracy: 0.9364
